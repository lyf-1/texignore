# %%
import numpy as np
import deep_laa_support as dls
import random
import sys
import tensorflow as tf
from sklearn.cluster import KMeans

# convert data from .mat to .npz
# in_file = "feature_31_L"
# dls.convert_mat_to_one_hot_npz(in_file)
# print('file ' + in_file + '.npz ' 'saved.')

# read data
filename = 'feature_rotten_tomatoes'
# filename = 'feature_31_L'
data_all = np.load(filename +'.npz')
print('File ' + filename + '.npz ' 'loaded.')
user_labels = data_all['user_labels']
true_labels = data_all['true_labels']
category_size = data_all['category_num']
source_num = data_all['source_num']
feature = data_all['feature']
_, feature_size = np.shape(feature)
n_samples, _ = np.shape(true_labels)

#================= basic parameters =====================
# define batch size (use all samples in one batch)
batch_size = n_samples # n_samples
cluster_num = 200
T = 1 # mc_sampling_times

if np.max(feature) <= 1 and np.min(feature) >= 0:
    flag_node_type = 'Bernoulli'
else:
    flag_node_type = 'Gaussian'   
print('Using ' + flag_node_type + ' output nodes.')

#================= encoder q(y|l) and q(h|x) =====================
with tf.name_scope('encoder'):
    #================= q(y|l) =====================
    # define input l (source label vectors)
    input_size = source_num * category_size
    with tf.variable_scope('q_yl'):
        l = tf.placeholder(dtype=tf.float32, shape=[batch_size, input_size], name='l_input')
        pi_yl, weights_yl, biases_yl = dls.LAA_encoder(l, batch_size, source_num, category_size)
    # loss: cross entropy between y_classifier and y_target for pre-training classifier
    with tf.variable_scope('q_yl'):
        pi_yl_target = tf.placeholder(dtype=tf.float32, shape=[batch_size, category_size], name='pi_yl_target')
        loss_yl = dls.LAA_loss_classifier(pi_yl, pi_yl_target)
    # optimizier
    learning_rate_yl = 0.01
    optimizer_pre_train_yl = tf.train.AdamOptimizer(learning_rate=learning_rate_yl).minimize(loss_yl)

    #================= q(h|x) =====================
    h1_size_encoder = int(np.floor(feature_size/2.0))
    h2_size_encoder = 100 # int(np.floor(feature_size/4.0))
    embedding_size = 50 # int(np.floor(feature_size/8.0))
    h1_size_decoder = 100 # int(np.floor(feature_size/4.0))
    h2_size_decoder = int(np.floor(feature_size/2.0))
    # h1_size_encoder = int(np.floor(feature_size/2.0))
    # h2_size_encoder = int(np.floor(feature_size/4.0))
    # embedding_size = int(np.floor(feature_size/8.0))
    # h1_size_decoder = int(np.floor(feature_size/4.0))
    # h2_size_decoder = int(np.floor(feature_size/2.0))
    with tf.variable_scope('q_hx'):
        x = tf.placeholder(dtype=tf.float32, shape=[batch_size, feature_size], name='x_input')
        # mu_hx[batch_size, embedding_size]
        # sigma_hx[batch_size, embedding_size]
        with tf.variable_scope('feature_encoder_h1'):
            _h1_encoder, w1_encoder, b1_encoder = dls.full_connect_relu_BN(x, [feature_size, h1_size_encoder])
        with tf.variable_scope('feature_encoder_h2'):
            _h2_encoder, w2_encoder, b2_encoder = dls.full_connect_relu_BN(_h1_encoder, [h1_size_encoder, h2_size_encoder])
        with tf.variable_scope('feature_encoder_mu'):
            mu_hx, w_mu_encoder, b_mu_encoder = dls.full_connect(_h2_encoder, [h2_size_encoder, embedding_size])
        with tf.variable_scope('feature_encoder_sigma'):
            sigma_hx, w_sigma_encoder, b_sigma_encoder = dls.full_connect(_h2_encoder, [h2_size_encoder, embedding_size])
        # mu_hx, sigma_hx = dls.vae_encoder(x, feature_size, h1_size_encoder, h2_size_encoder, embedding_size)
        # embedding_h[batch_size, T, embedding_size]
        embedding_h = tf.reshape(mu_hx, [batch_size, 1, embedding_size]) \
            + tf.reshape(sigma_hx, [batch_size, 1, -1]) \
            * tf.random_normal(shape=[batch_size, T, embedding_size], mean=0, stddev=1, dtype=tf.float32)

    with tf.variable_scope('q_hx_AE'):
        # x_reconstr, _, _ = dls.vae_decoder(mu_hx, embedding_size, h1_size_decoder, h2_size_decoder, feature_size)
        with tf.variable_scope('feature_decoder_h1'):
            _h1_decoder, w1_decoder, b1_decoder = dls.full_connect_relu_BN(mu_hx, [embedding_size, h1_size_decoder])
        with tf.variable_scope('feature_decoder_h2'):
            _h2_decoder, w2_decoder, b2_decoder = dls.full_connect_relu_BN(_h1_decoder, [h1_size_decoder, h2_size_decoder])
        with tf.variable_scope('feature_decoder_rho'):
            if flag_node_type == 'Bernoulli':
                x_reconstr, w_rho_decoder, b_rho_decoder = dls.full_connect_sigmoid(_h2_decoder, [h2_size_decoder, feature_size])
            elif flag_node_type == 'Gaussian':
                x_reconstr, w_rho_decoder, b_rho_decoder = dls.full_connect(_h2_decoder, [h2_size_decoder, feature_size])
        
        # Bernoulli
        loss_cross_entropy_AE = -tf.reduce_mean(tf.reduce_sum(x*tf.log(1e-10+x_reconstr) + (1.0-x)*tf.log(1e-10+(1.0-x_reconstr)), -1))
        # Gaussian
        loss_square_AE = 0.5 * tf.reduce_mean(tf.square(x_reconstr - x))
        constraint_w_AE = 0.5 * (tf.reduce_mean(tf.square(w1_encoder)) + tf.reduce_mean(tf.square(b1_encoder))
            + tf.reduce_mean(tf.square(w2_encoder)) + tf.reduce_mean(tf.square(b2_encoder))
            + tf.reduce_mean(tf.square(w_mu_encoder)) + tf.reduce_mean(tf.square(b_mu_encoder))
            + tf.reduce_mean(tf.square(w1_decoder)) + tf.reduce_mean(tf.square(b1_decoder))
            + tf.reduce_mean(tf.square(w2_decoder)) + tf.reduce_mean(tf.square(b2_decoder))
            + tf.reduce_mean(tf.square(w_rho_decoder)) + tf.reduce_mean(tf.square(b_rho_decoder)))
        if flag_node_type == 'Bernoulli':
            loss_AE = loss_cross_entropy_AE \
                + constraint_w_AE
        elif flag_node_type == 'Gaussian':
            loss_AE = loss_square_AE \
                + constraint_w_AE
        learning_rate_AE = 0.02
        optimizer_AE = tf.train.AdamOptimizer(learning_rate=learning_rate_AE).minimize(loss_AE)

    #================= p(x|h) =====================
    with tf.variable_scope('q_hx_AE'):
        with tf.variable_scope('feature_decoder_h1', reuse=True):
            _h_VAE = tf.reshape(embedding_h, [-1, embedding_size])
            _h1_decoder_VAE, _, _ = dls.full_connect_relu_BN(_h_VAE, [embedding_size, h1_size_decoder])
        with tf.variable_scope('feature_decoder_h2', reuse=True):
            _h2_decoder_VAE, _, _ = dls.full_connect_relu_BN(_h1_decoder_VAE, [h1_size_decoder, h2_size_decoder])
        with tf.variable_scope('feature_decoder_rho', reuse=True):
            if flag_node_type == 'Bernoulli':
                mu_xh, _, _ = dls.full_connect_sigmoid(_h2_decoder_VAE, [h2_size_decoder, feature_size])
            elif flag_node_type == 'Gaussian':
                mu_xh, _, _ = dls.full_connect(_h2_decoder_VAE, [h2_size_decoder, feature_size])
            mu_xh = tf.reshape(mu_xh, [batch_size, T, feature_size])
            
    print('Encoders are constructed.')
    
#================= decoder p(l|y), p(x|h), p(y|z), p(h|z) and p(z) =====================
with tf.name_scope('decoder'):
    #================= p(l|y) =====================
    with tf.variable_scope('p_ly'):
        # pi_ly[category_size, 1, source_num*category_size]
        pi_ly, weights_ly, biases_ly = dls.LAA_decoder(source_num, category_size)

        constraint_w_LAA = 0.5 * (tf.reduce_mean(tf.square(weights_ly)) + tf.reduce_mean(tf.square(biases_ly))
            + tf.reduce_mean(tf.square(weights_yl)) + tf.reduce_mean(tf.square(biases_yl)))
        
    #================= p(y|z) =====================
    with tf.variable_scope('p_yz'):
        # pi_yz[cluster_num, category_size]
        _pi_yz = tf.get_variable('pi_yz', dtype=tf.float32, 
                                initializer=tf.random_normal(shape=[cluster_num, category_size], mean=0, stddev=1, dtype=tf.float32))
        __pi_yz = tf.exp(_pi_yz)
        pi_yz = tf.div(__pi_yz, tf.reduce_sum(__pi_yz, -1, keepdims=True))
        
        pi_yz_assign = tf.placeholder(dtype=tf.float32, shape=[cluster_num, category_size], name='pi_yz_assign')
        initialize_pi_yz = tf.assign(_pi_yz, pi_yz_assign)
        
    #================= p(h|z) =====================
    with tf.variable_scope('p_hz'):
        # mu_hz[cluster_num, embedding_size]
        # sigma_hz[cluster_num, embedding_size]
        mu_hz = tf.get_variable('mu_hz', dtype=tf.float32, initializer=tf.random_normal(shape=[cluster_num, embedding_size], mean=0, stddev=1, dtype=tf.float32))
        sigma_hz = tf.get_variable('sigma_hz', dtype=tf.float32, initializer=tf.ones([cluster_num, embedding_size], dtype=tf.float32))

        mu_hz_assign = tf.placeholder(dtype=tf.float32, shape=[cluster_num, embedding_size], name='mu_hz_assign')
        initialize_mu_hz = tf.assign(mu_hz, mu_hz_assign)
        
    #================= p(z) =====================
    with tf.variable_scope('p_z'):
        # pi_z_prior[batch_size, cluster_num]
        pi_z_prior = tf.placeholder(dtype=tf.float32, shape=[batch_size, cluster_num], name='pi_z_prior')
        _pi_z = tf.get_variable('pi_z', dtype=tf.float32, initializer=tf.ones([batch_size, cluster_num]))
        __pi_z = tf.exp(_pi_z)
        pi_z = tf.div(__pi_z, tf.reduce_sum(__pi_z, -1, keepdims=True))

        pi_z_assign = tf.placeholder(dtype=tf.float32, shape=[batch_size, cluster_num], name='pi_z_assign')
        initialize_pi_z = tf.assign(_pi_z, pi_z_assign)
    print('Decoders are constructed.')
    
#================= elbo =====================
'''
q(h|x) log p(x|h)
q(y|l) log p(l|y)
q(h|x) log q(h|x)
q(y|l) log q(y|l)
q(z|x,l)q(h|x) log p(h|z)
q(z|x,l)q(y|l) log p(y|z)
q(z|x,l) log p(z)
q(z|x,l) log q(z|x,l)
q(z|x,l)
'''
with tf.name_scope('elbo'):
    #================= q(h|x) log p(x|h) =====================
    with tf.name_scope('q_hx_log_p_xh'):
        # reduce_mean along both T and batch_size
        _tmp = tf.reshape(x, [batch_size, 1, feature_size])
        if flag_node_type == 'Bernoulli':
            elbo_q_hx_log_p_xh = tf.reduce_mean(tf.reduce_sum(_tmp*tf.log(1e-10+mu_xh) + (1.0-_tmp)*tf.log(1e-10+(1.0-mu_xh)), -1))
        elif flag_node_type == 'Gaussian':
            elbo_q_hx_log_p_xh = -0.5 * tf.reduce_mean(tf.reduce_sum(tf.square(_tmp-mu_xh), -1))
    
    #================= q(y|l) log p(l|y) =====================
    with tf.name_scope('q_yl_log_p_ly'):
        elbo_q_yl_log_p_ly = -dls.LAA_loss_reconstr(l, pi_ly, pi_yl)
        
    #================= q(h|x) log q(h|x) =====================
    with tf.name_scope('q_hx_log_q_hx'):
        elbo_q_hx_log_q_hx = -0.5 * tf.reduce_mean(tf.reduce_sum(tf.log(1e-10+tf.square(sigma_hx)), -1))

    #================= q(y|l) log q(y|l) =====================
    with tf.name_scope('q_yl_log_q_yl'):
        elbo_q_yl_log_q_yl = tf.reduce_mean(tf.reduce_sum(pi_yl * tf.log(1e-10+pi_yl), -1))
    
    #================= q(z|x,l) =====================
    with tf.name_scope('q_zxl'):
        # p(h|z)[batch_size, T, cluster_num, 1]
        _h = tf.reshape(embedding_h, [batch_size, T, 1, embedding_size])
        _p_hz = -0.5 * tf.reduce_sum(
            tf.div(tf.square(_h-mu_hz), 1e-10+tf.square(sigma_hz)) 
            + tf.log(1e-10 + tf.square(sigma_hz)), -1, keepdims=True)
        # p_zhy[batch_size, T, cluster_num, category_size]
        _p_zhy = tf.log(1e-10+pi_yz) + _p_hz + tf.log(1e-10+tf.reshape(pi_z, [batch_size, 1, cluster_num, 1]))
        _p_zhy_max = tf.reduce_max(_p_zhy, 2, keepdims=True)
        p_zhy = tf.exp(_p_zhy - (_p_zhy_max + tf.log(1e-10+tf.reduce_sum(tf.exp(_p_zhy-_p_zhy_max), 2, keepdims=True))))
        
        # q_zxl[batch_size, cluster_num]
        # reduce_mean along both category_size and T
        _q_zxl = tf.reduce_sum(tf.reshape(pi_yl, [batch_size, 1, 1, category_size]) * p_zhy, -1)
        q_zxl = tf.reduce_mean(_q_zxl, 1)
        
        # z_index[batch_size]
        z_index = tf.argmax(q_zxl, 1)
        # cluster_pi_max[batch_size, category_size]
        # cluster_pi_avg[batch_size, category_size]
        cluster_pi_max = tf.gather(pi_yz, z_index)
        cluster_pi_avg = tf.matmul(q_zxl, pi_yz)
        
    #================= q(z|x,l)q(h|x) log p(h|z) =====================
    #================= q(h|x) log p(h|z) [batch_size, cluster_num] =====================
    with tf.name_scope('q_zxl_q_hx_log_p_hz'):
        # mu_hx[batch_size, embedding_size]
        # sigma_hx[batch_size, embedding_size]
        # mu_hz[cluster_num, embedding_size]
        # sigma_hz[cluster_num, embedding_size]
        _part_1 = tf.div(tf.square(tf.reshape(mu_hx, [batch_size, 1, embedding_size]) - mu_hz), 1e-10+tf.square(sigma_hz))
        _part_2 = tf.div(tf.square(tf.reshape(sigma_hx, [batch_size, 1, -1])), 1e-10+tf.square(sigma_hz))
        _part_3 = tf.log(1e-10 + tf.square(sigma_hz))
        # elbo_q_hx_log_p_hz[batch_size, cluster_num]
        elbo_q_hx_log_p_hz = -0.5 * tf.reduce_sum(_part_1 + _part_2 + _part_3, -1)
        elbo_q_zxl_q_hx_log_p_hz = tf.reduce_mean(tf.reduce_sum(q_zxl * elbo_q_hx_log_p_hz, -1))
    
    #================= q(z|x,l)q(y|l) log p(y|z) =====================
    #================= q(y|l) log p(y|z) [batch_size, cluster_num] =====================
    with tf.name_scope('q_zxl_q_yl_log_p_yz'):
        # pi_yz[cluster_num, category_size]
        # pi_yl[batch_size, category_size]
        # elbo_q_yl_log_p_yz[batch_size, cluster_num]
        elbo_q_yl_log_p_yz = tf.reduce_sum(tf.reshape(pi_yl, [batch_size, 1, category_size]) * tf.log(1e-10 + pi_yz), -1)
        elbo_q_zxl_q_yl_log_p_yz = tf.reduce_mean(tf.reduce_sum(q_zxl * elbo_q_yl_log_p_yz, -1))
    
    #================= q(z|x,l) log p(z) =====================
    #================= log p(z) [cluster_num] =====================
    with tf.name_scope('q_zxl_log_p_z'):
        # elbo_log_p_z[batch_size, cluster_num]
        elbo_log_p_z = tf.log(1e-10 + pi_z)
        elbo_q_zxl_log_p_z = tf.reduce_mean(tf.reduce_sum(q_zxl * elbo_log_p_z, -1))
    
    #================= q(z|x,l) log q(z|x,l) =====================
    with tf.name_scope('q_zxl_log_q_zxl'):
        # q_zxl[batch_size, cluster_num]
        elbo_q_zxl_log_q_zxl = tf.reduce_mean(tf.reduce_sum(q_zxl * tf.log(1e-10 + q_zxl), -1))
    
    #================= overall elbo =====================
    elbo = elbo_q_hx_log_p_xh + elbo_q_yl_log_p_ly - elbo_q_hx_log_q_hx - elbo_q_yl_log_q_yl \
        + elbo_q_zxl_q_hx_log_p_hz + elbo_q_zxl_q_yl_log_p_yz + elbo_q_zxl_log_p_z - elbo_q_zxl_log_q_zxl    
    
    q_zxl_entropy = -elbo_q_zxl_log_q_zxl
    
    with tf.variable_scope('regularization_prior'):
        mu_hz_prior_mu = tf.placeholder(dtype=tf.float32, shape=[cluster_num, embedding_size], name='mu_hz_prior_mu')
        # sigma_hz_prior_alpha = tf.placeholder(dtype=tf.float32, shape=[cluster_num, embedding_size], name='sigma_hz_prior')
        pi_yz_prior = tf.placeholder(dtype=tf.float32, shape=[cluster_num, category_size], name='pi_yz_prior')
    
        constraint_prior = 0.5*tf.reduce_mean(tf.square(mu_hz - mu_hz_prior_mu)) \
            - tf.reduce_mean(pi_yz_prior * tf.log(1e-10+pi_yz)) \
            - tf.reduce_mean(pi_z_prior * tf.log(1e-10+pi_z)) \
            + tf.reduce_mean(1.0*tf.log(1e-10+tf.square(sigma_hz))+tf.div(2.0, 1e-10+tf.square(sigma_hz)))
    
    loss_overall = -elbo \
        + constraint_w_AE \
        + constraint_w_LAA \
        + 1.0 * constraint_prior
    
    # optimizier
    learning_rate_overall = 0.001
    optimizer_overall = tf.train.AdamOptimizer(learning_rate=learning_rate_overall).minimize(loss_overall)

    print('Clustering-based label-aware autoencoder is constructed.')

saver = tf.train.Saver()
# Out:
# File feature_rotten_tomatoes.npz loaded.
# Using Gaussian output nodes.
# Encoders are constructed.
# Decoders are constructed.
# Clustering-based label-aware autoencoder is constructed.

# %%
#================= training and inference =====================
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    #================= pre-train pi_yl =====================
    # assign batch variables (use whole data in one batch)
    # define majority voting regularizer
    majority_y = dls.get_majority_y(user_labels, source_num, category_size)
    # pre-train classifier
    print("Pre-train pi_yl ...")
    epochs = 50
    for epoch in range(epochs):
        _, monitor_pi_yl = sess.run([optimizer_pre_train_yl, pi_yl], 
            feed_dict={l:user_labels, pi_yl_target:majority_y})
        if epoch % 10 == 0:
            hit_num = dls.cal_hit_num(true_labels, monitor_pi_yl)
            print("epoch: {0} accuracy: {1}".format(epoch, float(hit_num)/n_samples))
    
    print("Pre-train hx_AE ...")
    epochs = 2000
    for epoch in range(epochs):
        _, monitor_loss_square_AE, monitor_mu_hx = sess.run([optimizer_AE, loss_square_AE, mu_hx], 
            feed_dict={x:feature})
        if epoch % 50 == 0:
            print("epoch: {0} loss: {1}".format(epoch, monitor_loss_square_AE))    
    
    #================= calculate initial parameters =====================
    clustering_result = KMeans(n_clusters=cluster_num).fit(np.concatenate((monitor_mu_hx, majority_y), 1))
    # pi_z_prior_cluster = np.ones([n_samples, cluster_num]) / cluster_num
    pi_z_prior_cluster = dls.convert_to_one_hot(clustering_result.labels_, cluster_num, smooth=0.2)
    _ = sess.run(initialize_mu_hz, {mu_hz_assign:clustering_result.cluster_centers_[:, 0:embedding_size]})
    # pi_yz_prior_cluster = np.ones([cluster_num, category_size]) / cluster_num
    pi_yz_prior_cluster = dls.get_cluster_majority_y(
        clustering_result.labels_, user_labels, cluster_num, source_num, category_size)
    _ = sess.run(initialize_pi_yz, {pi_yz_assign:pi_yz_prior_cluster})
    _ = sess.run(initialize_pi_z, {pi_z_assign:pi_z_prior_cluster})
    
    mu_hz_prior_mu_cluster = clustering_result.cluster_centers_[:, 0:embedding_size]
    
    predict_label = np.zeros([batch_size, category_size])
    for i in range(batch_size):
        predict_label[i] = pi_yz_prior_cluster[clustering_result.labels_[i], :]
    print("Initial clustering accuracy: {0}".format(float(dls.cal_hit_num(true_labels, predict_label)) / n_samples))
    
    #================= save current model =====================
    saved_path = saver.save(sess, './my_model')
# Out:
# Pre-train pi_yl ...
# epoch: 0 accuracy: 0.6949389877975595
# epoch: 10 accuracy: 0.8825765153030606
# epoch: 20 accuracy: 0.8857771554310863
# epoch: 30 accuracy: 0.8821764352870574
# epoch: 40 accuracy: 0.8789757951590318
# Pre-train hx_AE ...
# epoch: 0 loss: 0.0034235448110848665
# epoch: 50 loss: 0.003666071454063058
# epoch: 100 loss: 0.00311955320648849
# epoch: 150 loss: 0.0031102949287742376
# epoch: 200 loss: 0.003106012474745512
# epoch: 250 loss: 0.0031006676144897938
# epoch: 300 loss: 0.0030889601912349463
# epoch: 350 loss: 0.003067582380026579
# epoch: 400 loss: 0.0030528968200087547
# epoch: 450 loss: 0.0030483026057481766
# epoch: 500 loss: 0.0030430324841290712
# epoch: 550 loss: 0.0030466991011053324
# epoch: 600 loss: 0.003037713235244155
# epoch: 650 loss: 0.0029859282076358795
# epoch: 700 loss: 0.002978849457576871
# epoch: 750 loss: 0.0029778298921883106
# epoch: 800 loss: 0.0029789551626890898
# epoch: 850 loss: 0.0029758764430880547
# epoch: 900 loss: 0.0029715222772210836
# epoch: 950 loss: 0.002975840587168932
# epoch: 1000 loss: 0.0029681818559765816
# epoch: 1050 loss: 0.0029545696452260017
# epoch: 1100 loss: 0.0029491004534065723
# epoch: 1150 loss: 0.0029502983670681715
# epoch: 1200 loss: 0.002937411656603217
# epoch: 1250 loss: 0.0029372619464993477
# epoch: 1300 loss: 0.00293058343231678
# epoch: 1350 loss: 0.0029754512943327427
# epoch: 1400 loss: 0.00290656927973032
# epoch: 1450 loss: 0.002893239725381136
# epoch: 1500 loss: 0.0028845849446952343
# epoch: 1550 loss: 0.00285095302388072
# epoch: 1600 loss: 0.0028314830269664526
# epoch: 1650 loss: 0.0028075622394680977
# epoch: 1700 loss: 0.0027954294346272945
# epoch: 1750 loss: 0.0027669244445860386
# epoch: 1800 loss: 0.002761370036751032
# epoch: 1850 loss: 0.0027306259144097567
# epoch: 1900 loss: 0.002704774495214224
# epoch: 1950 loss: 0.002688826760277152
# Initial clustering accuracy: 0.8849769953990798

# %%
with tf.Session() as sess:
    saver.restore(sess, './my_model')
    
    print("Train overall net ...")
    epochs = 2000
    for epoch in range(epochs):
        _, monitor_loss_overall, monitor_pi_yl, monitor_cluster_pi_max, monitor_cluster_pi_avg, \
            monitor_constraint_w_AE, monitor_constraint_prior = sess.run(
                [optimizer_overall, loss_overall, pi_yl, cluster_pi_max, cluster_pi_avg, constraint_w_AE, constraint_prior], 
                feed_dict={l:user_labels, x:feature, 
                           pi_z_prior:pi_z_prior_cluster, 
                           mu_hz_prior_mu:mu_hz_prior_mu_cluster, 
                           pi_yz_prior:pi_yz_prior_cluster})
        if epoch % 10 == 0:
            print("epoch: {0} loss: {1}".format(epoch, monitor_loss_overall))
            print("epoch: {0} loss: {1}".format(epoch, monitor_constraint_w_AE))
            print("epoch: {0} loss: {1}".format(epoch, monitor_constraint_prior))
            hit_num_object_level = dls.cal_hit_num(true_labels, monitor_pi_yl)
            hit_num_cluster_level_max = dls.cal_hit_num(true_labels, monitor_cluster_pi_max)
            hit_num_cluster_level_avg = dls.cal_hit_num(true_labels, monitor_cluster_pi_avg)
            print("epoch: {0} accuracy(object level): {1}".format(epoch, float(hit_num_object_level)/n_samples))
            print("epoch: {0} accuracy(cluster level max): {1}".format(epoch, float(hit_num_cluster_level_max)/n_samples))
            print("epoch: {0} accuracy(cluster level avg): {1}".format(epoch, float(hit_num_cluster_level_avg)/n_samples))
    print("Training overall net. Done!")
    
    monitor_q_zxl = sess.run(q_zxl, 
                feed_dict={l:user_labels, x:feature, 
                           pi_z_prior:pi_z_prior_cluster, 
                           mu_hz_prior_mu:mu_hz_prior_mu_cluster, 
                           pi_yz_prior:pi_yz_prior_cluster})
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model
# Train overall net ...
# epoch: 0 loss: 212.71759033203125
# epoch: 0 loss: 0.0003140648186672479
# epoch: 0 loss: 2.2800440788269043
# epoch: 0 accuracy(object level): 0.8791758351670335
# epoch: 0 accuracy(cluster level max): 0.8849769953990798
# epoch: 0 accuracy(cluster level avg): 0.8797759551910382
# epoch: 10 loss: 119.65145874023438
# epoch: 10 loss: 0.00034990295534953475
# epoch: 10 loss: 2.2991762161254883
# epoch: 10 accuracy(object level): 0.8789757951590318
# epoch: 10 accuracy(cluster level max): 0.8811762352470494
# epoch: 10 accuracy(cluster level avg): 0.8701740348069614
# epoch: 20 loss: 90.2087631225586
# epoch: 20 loss: 0.0003818291297648102
# epoch: 20 loss: 2.319314479827881
# epoch: 20 accuracy(object level): 0.8779755951190238
# epoch: 20 accuracy(cluster level max): 0.8799759951990398
# epoch: 20 accuracy(cluster level avg): 0.8569713942788558
# epoch: 30 loss: 74.88299560546875
# epoch: 30 loss: 0.0004009485128335655
# epoch: 30 loss: 2.339801788330078
# epoch: 30 accuracy(object level): 0.8775755151030206
# epoch: 30 accuracy(cluster level max): 0.8779755951190238
# epoch: 30 accuracy(cluster level avg): 0.8521704340868174
# epoch: 40 loss: 65.45552062988281
# epoch: 40 loss: 0.00041430158307775855
# epoch: 40 loss: 2.3601107597351074
# epoch: 40 accuracy(object level): 0.8775755151030206
# epoch: 40 accuracy(cluster level max): 0.8711742348469694
# epoch: 40 accuracy(cluster level avg): 0.8469693938787758
# epoch: 50 loss: 59.134342193603516
# epoch: 50 loss: 0.00042776638292707503
# epoch: 50 loss: 2.3798155784606934
# epoch: 50 accuracy(object level): 0.8771754350870175
# epoch: 50 accuracy(cluster level max): 0.8695739147829565
# epoch: 50 accuracy(cluster level avg): 0.8451690338067613
# epoch: 60 loss: 54.76413345336914
# epoch: 60 loss: 0.00044307063217274845
# epoch: 60 loss: 2.39852237701416
# epoch: 60 accuracy(object level): 0.8777755551110222
# epoch: 60 accuracy(cluster level max): 0.8699739947989598
# epoch: 60 accuracy(cluster level avg): 0.8411682336467293
# epoch: 70 loss: 51.24186325073242
# epoch: 70 loss: 0.0004588395531754941
# epoch: 70 loss: 2.4160523414611816
# epoch: 70 accuracy(object level): 0.8781756351270255
# epoch: 70 accuracy(cluster level max): 0.8659731946389277
# epoch: 70 accuracy(cluster level avg): 0.8449689937987598
# epoch: 80 loss: 48.82090759277344
# epoch: 80 loss: 0.00047124188859015703
# epoch: 80 loss: 2.432393789291382
# epoch: 80 accuracy(object level): 0.8787757551510302
# epoch: 80 accuracy(cluster level max): 0.8573714742948589
# epoch: 80 accuracy(cluster level avg): 0.8429685937187438
# epoch: 90 loss: 47.03193283081055
# epoch: 90 loss: 0.0004814777057617903
# epoch: 90 loss: 2.4475440979003906
# epoch: 90 accuracy(object level): 0.8789757951590318
# epoch: 90 accuracy(cluster level max): 0.8563712742548509
# epoch: 90 accuracy(cluster level avg): 0.844368873774755
# epoch: 100 loss: 45.462669372558594
# epoch: 100 loss: 0.0004864193615503609
# epoch: 100 loss: 2.461428165435791
# epoch: 100 accuracy(object level): 0.8791758351670335
# epoch: 100 accuracy(cluster level max): 0.8565713142628526
# epoch: 100 accuracy(cluster level avg): 0.8441688337667533
# epoch: 110 loss: 44.15301513671875
# epoch: 110 loss: 0.0004909497802145779
# epoch: 110 loss: 2.473942279815674
# epoch: 110 accuracy(object level): 0.8795759151830366
# epoch: 110 accuracy(cluster level max): 0.8507701540308061
# epoch: 110 accuracy(cluster level avg): 0.8447689537907581
# epoch: 120 loss: 43.19565963745117
# epoch: 120 loss: 0.0004958240897394717
# epoch: 120 loss: 2.4849870204925537
# epoch: 120 accuracy(object level): 0.8801760352070415
# epoch: 120 accuracy(cluster level max): 0.8511702340468094
# epoch: 120 accuracy(cluster level avg): 0.8485697139427886
# epoch: 130 loss: 42.441062927246094
# epoch: 130 loss: 0.0004994985065422952
# epoch: 130 loss: 2.4946658611297607
# epoch: 130 accuracy(object level): 0.8805761152230446
# epoch: 130 accuracy(cluster level max): 0.8477695539107821
# epoch: 130 accuracy(cluster level avg): 0.8473694738947789
# epoch: 140 loss: 41.7232780456543
# epoch: 140 loss: 0.0005030992906540632
# epoch: 140 loss: 2.5031678676605225
# epoch: 140 accuracy(object level): 0.880376075215043
# epoch: 140 accuracy(cluster level max): 0.8537707541508301
# epoch: 140 accuracy(cluster level avg): 0.8509701940388078
# epoch: 150 loss: 41.12472152709961
# epoch: 150 loss: 0.0005035210633650422
# epoch: 150 loss: 2.5103914737701416
# epoch: 150 accuracy(object level): 0.8831766353270654
# epoch: 150 accuracy(cluster level max): 0.8511702340468094
# epoch: 150 accuracy(cluster level avg): 0.8535707141428286
# epoch: 160 loss: 40.63603591918945
# epoch: 160 loss: 0.0005058411625213921
# epoch: 160 loss: 2.5162672996520996
# epoch: 160 accuracy(object level): 0.8857771554310863
# epoch: 160 accuracy(cluster level max): 0.8509701940388078
# epoch: 160 accuracy(cluster level avg): 0.8557711542308462
# epoch: 170 loss: 40.21857452392578
# epoch: 170 loss: 0.0005077030509710312
# epoch: 170 loss: 2.520984172821045
# epoch: 170 accuracy(object level): 0.8887777555511103
# epoch: 170 accuracy(cluster level max): 0.8475695139027806
# epoch: 170 accuracy(cluster level avg): 0.860372074414883
# epoch: 180 loss: 39.8945198059082
# epoch: 180 loss: 0.0005075897788628936
# epoch: 180 loss: 2.5247085094451904
# epoch: 180 accuracy(object level): 0.8907781556311263
# epoch: 180 accuracy(cluster level max): 0.8563712742548509
# epoch: 180 accuracy(cluster level avg): 0.8637727545509102
# epoch: 190 loss: 40.054351806640625
# epoch: 190 loss: 0.0005097214598208666
# epoch: 190 loss: 2.5273303985595703
# epoch: 190 accuracy(object level): 0.8911782356471294
# epoch: 190 accuracy(cluster level max): 0.8537707541508301
# epoch: 190 accuracy(cluster level avg): 0.8635727145429086
# epoch: 200 loss: 39.9145622253418
# epoch: 200 loss: 0.0005138090346008539
# epoch: 200 loss: 2.529616355895996
# epoch: 200 accuracy(object level): 0.8921784356871374
# epoch: 200 accuracy(cluster level max): 0.8529705941188238
# epoch: 200 accuracy(cluster level avg): 0.8657731546309262
# epoch: 210 loss: 39.557804107666016
# epoch: 210 loss: 0.0005182513850741088
# epoch: 210 loss: 2.53167986869812
# epoch: 210 accuracy(object level): 0.8927785557111422
# epoch: 210 accuracy(cluster level max): 0.8555711142228446
# epoch: 210 accuracy(cluster level avg): 0.8691738347669534
# epoch: 220 loss: 39.34720230102539
# epoch: 220 loss: 0.0005231918185018003
# epoch: 220 loss: 2.532841920852661
# epoch: 220 accuracy(object level): 0.8935787157431486
# epoch: 220 accuracy(cluster level max): 0.8559711942388478
# epoch: 220 accuracy(cluster level avg): 0.8685737147429486
# epoch: 230 loss: 39.23757553100586
# epoch: 230 loss: 0.0005287655512802303
# epoch: 230 loss: 2.533050537109375
# epoch: 230 accuracy(object level): 0.8939787957591518
# epoch: 230 accuracy(cluster level max): 0.8599719943988797
# epoch: 230 accuracy(cluster level avg): 0.875375075015003
# epoch: 240 loss: 39.14049530029297
# epoch: 240 loss: 0.0005340384086593986
# epoch: 240 loss: 2.5327625274658203
# epoch: 240 accuracy(object level): 0.8943788757751551
# epoch: 240 accuracy(cluster level max): 0.8573714742948589
# epoch: 240 accuracy(cluster level avg): 0.8729745949189838
# epoch: 250 loss: 39.140804290771484
# epoch: 250 loss: 0.0005430211313068867
# epoch: 250 loss: 2.5323615074157715
# epoch: 250 accuracy(object level): 0.8951790358071614
# epoch: 250 accuracy(cluster level max): 0.8545709141828366
# epoch: 250 accuracy(cluster level avg): 0.8797759551910382
# epoch: 260 loss: 39.085514068603516
# epoch: 260 loss: 0.0005534689407795668
# epoch: 260 loss: 2.5321545600891113
# epoch: 260 accuracy(object level): 0.8955791158231646
# epoch: 260 accuracy(cluster level max): 0.8627725545109022
# epoch: 260 accuracy(cluster level avg): 0.8761752350470094
# epoch: 270 loss: 38.93113327026367
# epoch: 270 loss: 0.0005604896578006446
# epoch: 270 loss: 2.532102108001709
# epoch: 270 accuracy(object level): 0.8965793158631726
# epoch: 270 accuracy(cluster level max): 0.8641728345669134
# epoch: 270 accuracy(cluster level avg): 0.8785757151430286
# epoch: 280 loss: 38.90250015258789
# epoch: 280 loss: 0.000569306081160903
# epoch: 280 loss: 2.5315823554992676
# epoch: 280 accuracy(object level): 0.8971794358871774
# epoch: 280 accuracy(cluster level max): 0.8575715143028606
# epoch: 280 accuracy(cluster level avg): 0.8799759951990398
# epoch: 290 loss: 38.84546661376953
# epoch: 290 loss: 0.0005812905728816986
# epoch: 290 loss: 2.5301389694213867
# epoch: 290 accuracy(object level): 0.8971794358871774
# epoch: 290 accuracy(cluster level max): 0.8591718343668734
# epoch: 290 accuracy(cluster level avg): 0.8801760352070415
# epoch: 300 loss: 38.76754379272461
# epoch: 300 loss: 0.0005927612655796111
# epoch: 300 loss: 2.528430700302124
# epoch: 300 accuracy(object level): 0.8975795159031806
# epoch: 300 accuracy(cluster level max): 0.8609721944388877
# epoch: 300 accuracy(cluster level avg): 0.8825765153030606
# epoch: 310 loss: 38.73283004760742
# epoch: 310 loss: 0.0006033835816197097
# epoch: 310 loss: 2.5267350673675537
# epoch: 310 accuracy(object level): 0.8981796359271854
# epoch: 310 accuracy(cluster level max): 0.8583716743348669
# epoch: 310 accuracy(cluster level avg): 0.8821764352870574
# epoch: 320 loss: 38.48049545288086
# epoch: 320 loss: 0.0006138171884231269
# epoch: 320 loss: 2.525012731552124
# epoch: 320 accuracy(object level): 0.8983796759351871
# epoch: 320 accuracy(cluster level max): 0.8589717943588717
# epoch: 320 accuracy(cluster level avg): 0.8831766353270654
# epoch: 330 loss: 38.18124771118164
# epoch: 330 loss: 0.0006196586764417589
# epoch: 330 loss: 2.5225632190704346
# epoch: 330 accuracy(object level): 0.8985797159431886
# epoch: 330 accuracy(cluster level max): 0.860372074414883
# epoch: 330 accuracy(cluster level avg): 0.8829765953190638
# epoch: 340 loss: 37.93341827392578
# epoch: 340 loss: 0.0006248974241316319
# epoch: 340 loss: 2.5192995071411133
# epoch: 340 accuracy(object level): 0.8987797559511902
# epoch: 340 accuracy(cluster level max): 0.8677735547109422
# epoch: 340 accuracy(cluster level avg): 0.8857771554310863
# epoch: 350 loss: 37.71984100341797
# epoch: 350 loss: 0.0006283134571276605
# epoch: 350 loss: 2.515394926071167
# epoch: 350 accuracy(object level): 0.8987797559511902
# epoch: 350 accuracy(cluster level max): 0.8675735147029406
# epoch: 350 accuracy(cluster level avg): 0.8871774354870974
# epoch: 360 loss: 37.5548210144043
# epoch: 360 loss: 0.0006291887257248163
# epoch: 360 loss: 2.5110602378845215
# epoch: 360 accuracy(object level): 0.8991798359671934
# epoch: 360 accuracy(cluster level max): 0.868373674734947
# epoch: 360 accuracy(cluster level avg): 0.888377675535107
# epoch: 370 loss: 37.406009674072266
# epoch: 370 loss: 0.000628516252618283
# epoch: 370 loss: 2.506594657897949
# epoch: 370 accuracy(object level): 0.8993798759751951
# epoch: 370 accuracy(cluster level max): 0.8679735947189438
# epoch: 370 accuracy(cluster level avg): 0.8865773154630926
# epoch: 380 loss: 37.293601989746094
# epoch: 380 loss: 0.0006276669446378946
# epoch: 380 loss: 2.5021419525146484
# epoch: 380 accuracy(object level): 0.8995799159831966
# epoch: 380 accuracy(cluster level max): 0.8675735147029406
# epoch: 380 accuracy(cluster level avg): 0.8881776355271054
# epoch: 390 loss: 37.172996520996094
# epoch: 390 loss: 0.000625578046310693
# epoch: 390 loss: 2.497750759124756
# epoch: 390 accuracy(object level): 0.8997799559911982
# epoch: 390 accuracy(cluster level max): 0.8677735547109422
# epoch: 390 accuracy(cluster level avg): 0.8887777555511103
# epoch: 400 loss: 37.07917404174805
# epoch: 400 loss: 0.0006239587673917413
# epoch: 400 loss: 2.4934356212615967
# epoch: 400 accuracy(object level): 0.8997799559911982
# epoch: 400 accuracy(cluster level max): 0.8655731146229246
# epoch: 400 accuracy(cluster level avg): 0.8895779155831166
# epoch: 410 loss: 36.967098236083984
# epoch: 410 loss: 0.0006212957086972892
# epoch: 410 loss: 2.4890668392181396
# epoch: 410 accuracy(object level): 0.8993798759751951
# epoch: 410 accuracy(cluster level max): 0.8689737947589518
# epoch: 410 accuracy(cluster level avg): 0.8911782356471294
# epoch: 420 loss: 36.88227844238281
# epoch: 420 loss: 0.0006176286260597408
# epoch: 420 loss: 2.4846854209899902
# epoch: 420 accuracy(object level): 0.8999799959991999
# epoch: 420 accuracy(cluster level max): 0.8697739547909582
# epoch: 420 accuracy(cluster level avg): 0.8921784356871374
# epoch: 430 loss: 36.80552291870117
# epoch: 430 loss: 0.0006154121365398169
# epoch: 430 loss: 2.4802584648132324
# epoch: 430 accuracy(object level): 0.8997799559911982
# epoch: 430 accuracy(cluster level max): 0.8717743548709742
# epoch: 430 accuracy(cluster level avg): 0.8927785557111422
# epoch: 440 loss: 36.72036361694336
# epoch: 440 loss: 0.0006122326012700796
# epoch: 440 loss: 2.4758810997009277
# epoch: 440 accuracy(object level): 0.8997799559911982
# epoch: 440 accuracy(cluster level max): 0.8687737547509502
# epoch: 440 accuracy(cluster level avg): 0.8925785157031406
# epoch: 450 loss: 36.65070343017578
# epoch: 450 loss: 0.0006089590024203062
# epoch: 450 loss: 2.4714324474334717
# epoch: 450 accuracy(object level): 0.9001800360072014
# epoch: 450 accuracy(cluster level max): 0.8709741948389678
# epoch: 450 accuracy(cluster level avg): 0.8929785957191438
# epoch: 460 loss: 36.57241439819336
# epoch: 460 loss: 0.0006061440799385309
# epoch: 460 loss: 2.4669291973114014
# epoch: 460 accuracy(object level): 0.9001800360072014
# epoch: 460 accuracy(cluster level max): 0.8705741148229645
# epoch: 460 accuracy(cluster level avg): 0.8943788757751551
# epoch: 470 loss: 36.5106086730957
# epoch: 470 loss: 0.0006043832981958985
# epoch: 470 loss: 2.462409496307373
# epoch: 470 accuracy(object level): 0.9001800360072014
# epoch: 470 accuracy(cluster level max): 0.873374674934987
# epoch: 470 accuracy(cluster level avg): 0.8937787557511502
# epoch: 480 loss: 36.432613372802734
# epoch: 480 loss: 0.0006021359586156905
# epoch: 480 loss: 2.45792555809021
# epoch: 480 accuracy(object level): 0.8999799959991999
# epoch: 480 accuracy(cluster level max): 0.875375075015003
# epoch: 480 accuracy(cluster level avg): 0.8939787957591518
# epoch: 490 loss: 36.36372756958008
# epoch: 490 loss: 0.0005996859399601817
# epoch: 490 loss: 2.4534127712249756
# epoch: 490 accuracy(object level): 0.9001800360072014
# epoch: 490 accuracy(cluster level max): 0.8759751950390078
# epoch: 490 accuracy(cluster level avg): 0.8931786357271454
# epoch: 500 loss: 36.29602813720703
# epoch: 500 loss: 0.0005977331893518567
# epoch: 500 loss: 2.4489502906799316
# epoch: 500 accuracy(object level): 0.9001800360072014
# epoch: 500 accuracy(cluster level max): 0.8741748349669934
# epoch: 500 accuracy(cluster level avg): 0.8943788757751551
# epoch: 510 loss: 36.232608795166016
# epoch: 510 loss: 0.0005945630837231874
# epoch: 510 loss: 2.444573402404785
# epoch: 510 accuracy(object level): 0.9003800760152031
# epoch: 510 accuracy(cluster level max): 0.875375075015003
# epoch: 510 accuracy(cluster level avg): 0.8957791558311662
# epoch: 520 loss: 36.18573760986328
# epoch: 520 loss: 0.0005922192940488458
# epoch: 520 loss: 2.440190076828003
# epoch: 520 accuracy(object level): 0.9009801960392079
# epoch: 520 accuracy(cluster level max): 0.876375275055011
# epoch: 520 accuracy(cluster level avg): 0.8955791158231646
# epoch: 530 loss: 36.12491989135742
# epoch: 530 loss: 0.0005891516921110451
# epoch: 530 loss: 2.435809850692749
# epoch: 530 accuracy(object level): 0.9009801960392079
# epoch: 530 accuracy(cluster level max): 0.8767753550710142
# epoch: 530 accuracy(cluster level avg): 0.8949789957991598
# epoch: 540 loss: 36.06361389160156
# epoch: 540 loss: 0.0005873366026207805
# epoch: 540 loss: 2.4314584732055664
# epoch: 540 accuracy(object level): 0.9009801960392079
# epoch: 540 accuracy(cluster level max): 0.879375875175035
# epoch: 540 accuracy(cluster level avg): 0.8955791158231646
# epoch: 550 loss: 36.01157760620117
# epoch: 550 loss: 0.0005847550346516073
# epoch: 550 loss: 2.4271390438079834
# epoch: 550 accuracy(object level): 0.9013802760552111
# epoch: 550 accuracy(cluster level max): 0.879375875175035
# epoch: 550 accuracy(cluster level avg): 0.8963792758551711
# epoch: 560 loss: 35.95977783203125
# epoch: 560 loss: 0.0005823734099976718
# epoch: 560 loss: 2.4228153228759766
# epoch: 560 accuracy(object level): 0.9013802760552111
# epoch: 560 accuracy(cluster level max): 0.8809761952390478
# epoch: 560 accuracy(cluster level avg): 0.8955791158231646
# epoch: 570 loss: 35.911441802978516
# epoch: 570 loss: 0.0005798254860565066
# epoch: 570 loss: 2.418548822402954
# epoch: 570 accuracy(object level): 0.9015803160632127
# epoch: 570 accuracy(cluster level max): 0.8817763552710542
# epoch: 570 accuracy(cluster level avg): 0.8955791158231646
# epoch: 580 loss: 35.85926818847656
# epoch: 580 loss: 0.0005780889769084752
# epoch: 580 loss: 2.414348840713501
# epoch: 580 accuracy(object level): 0.9015803160632127
# epoch: 580 accuracy(cluster level max): 0.8829765953190638
# epoch: 580 accuracy(cluster level avg): 0.8985797159431886
# epoch: 590 loss: 35.79936981201172
# epoch: 590 loss: 0.0005761391366831958
# epoch: 590 loss: 2.410151481628418
# epoch: 590 accuracy(object level): 0.9013802760552111
# epoch: 590 accuracy(cluster level max): 0.8827765553110622
# epoch: 590 accuracy(cluster level avg): 0.8969793958791759
# epoch: 600 loss: 35.76594543457031
# epoch: 600 loss: 0.0005749156698584557
# epoch: 600 loss: 2.405994176864624
# epoch: 600 accuracy(object level): 0.9013802760552111
# epoch: 600 accuracy(cluster level max): 0.8829765953190638
# epoch: 600 accuracy(cluster level avg): 0.8973794758951791
# epoch: 610 loss: 35.71345901489258
# epoch: 610 loss: 0.0005732803838327527
# epoch: 610 loss: 2.401853084564209
# epoch: 610 accuracy(object level): 0.9019803960792159
# epoch: 610 accuracy(cluster level max): 0.8831766353270654
# epoch: 610 accuracy(cluster level avg): 0.8979795959191839
# epoch: 620 loss: 35.66580581665039
# epoch: 620 loss: 0.0005715704755857587
# epoch: 620 loss: 2.3977441787719727
# epoch: 620 accuracy(object level): 0.9019803960792159
# epoch: 620 accuracy(cluster level max): 0.882376475295059
# epoch: 620 accuracy(cluster level avg): 0.8987797559511902
# epoch: 630 loss: 35.617027282714844
# epoch: 630 loss: 0.0005700418259948492
# epoch: 630 loss: 2.3937206268310547
# epoch: 630 accuracy(object level): 0.9023804760952191
# epoch: 630 accuracy(cluster level max): 0.8839767953590718
# epoch: 630 accuracy(cluster level avg): 0.8997799559911982
# epoch: 640 loss: 35.58771896362305
# epoch: 640 loss: 0.0005685795331373811
# epoch: 640 loss: 2.3897504806518555
# epoch: 640 accuracy(object level): 0.9023804760952191
# epoch: 640 accuracy(cluster level max): 0.885377075415083
# epoch: 640 accuracy(cluster level avg): 0.8999799959991999
# epoch: 650 loss: 35.54188919067383
# epoch: 650 loss: 0.0005676888395100832
# epoch: 650 loss: 2.3857369422912598
# epoch: 650 accuracy(object level): 0.9025805161032207
# epoch: 650 accuracy(cluster level max): 0.886377275455091
# epoch: 650 accuracy(cluster level avg): 0.8993798759751951
# epoch: 660 loss: 35.50798416137695
# epoch: 660 loss: 0.0005668289959430695
# epoch: 660 loss: 2.381682872772217
# epoch: 660 accuracy(object level): 0.9025805161032207
# epoch: 660 accuracy(cluster level max): 0.8857771554310863
# epoch: 660 accuracy(cluster level avg): 0.9001800360072014
# epoch: 670 loss: 35.46540069580078
# epoch: 670 loss: 0.0005666752113029361
# epoch: 670 loss: 2.3777081966400146
# epoch: 670 accuracy(object level): 0.9025805161032207
# epoch: 670 accuracy(cluster level max): 0.8871774354870974
# epoch: 670 accuracy(cluster level avg): 0.9001800360072014
# epoch: 680 loss: 35.42184066772461
# epoch: 680 loss: 0.0005659671733155847
# epoch: 680 loss: 2.3737874031066895
# epoch: 680 accuracy(object level): 0.9021804360872174
# epoch: 680 accuracy(cluster level max): 0.886377275455091
# epoch: 680 accuracy(cluster level avg): 0.9007801560312062
# epoch: 690 loss: 35.38164138793945
# epoch: 690 loss: 0.0005652448162436485
# epoch: 690 loss: 2.369952440261841
# epoch: 690 accuracy(object level): 0.9021804360872174
# epoch: 690 accuracy(cluster level max): 0.8851770354070814
# epoch: 690 accuracy(cluster level avg): 0.9013802760552111
# epoch: 700 loss: 35.357177734375
# epoch: 700 loss: 0.0005642457981593907
# epoch: 700 loss: 2.366048812866211
# epoch: 700 accuracy(object level): 0.9023804760952191
# epoch: 700 accuracy(cluster level max): 0.8871774354870974
# epoch: 700 accuracy(cluster level avg): 0.9011802360472094
# epoch: 710 loss: 35.310302734375
# epoch: 710 loss: 0.0005637811264023185
# epoch: 710 loss: 2.3621537685394287
# epoch: 710 accuracy(object level): 0.9025805161032207
# epoch: 710 accuracy(cluster level max): 0.8871774354870974
# epoch: 710 accuracy(cluster level avg): 0.9025805161032207
# epoch: 720 loss: 35.2752571105957
# epoch: 720 loss: 0.0005631455569528043
# epoch: 720 loss: 2.3583807945251465
# epoch: 720 accuracy(object level): 0.9031806361272254
# epoch: 720 accuracy(cluster level max): 0.8871774354870974
# epoch: 720 accuracy(cluster level avg): 0.9019803960792159
# epoch: 730 loss: 35.23915481567383
# epoch: 730 loss: 0.0005628371145576239
# epoch: 730 loss: 2.3546361923217773
# epoch: 730 accuracy(object level): 0.9031806361272254
# epoch: 730 accuracy(cluster level max): 0.888377675535107
# epoch: 730 accuracy(cluster level avg): 0.9023804760952191
# epoch: 740 loss: 35.20729064941406
# epoch: 740 loss: 0.0005636004498228431
# epoch: 740 loss: 2.3508992195129395
# epoch: 740 accuracy(object level): 0.9029805961192239
# epoch: 740 accuracy(cluster level max): 0.8877775555111023
# epoch: 740 accuracy(cluster level avg): 0.9021804360872174
# epoch: 750 loss: 35.17504119873047
# epoch: 750 loss: 0.000563243345823139
# epoch: 750 loss: 2.3471741676330566
# epoch: 750 accuracy(object level): 0.9031806361272254
# epoch: 750 accuracy(cluster level max): 0.8891778355671134
# epoch: 750 accuracy(cluster level avg): 0.9025805161032207
# epoch: 760 loss: 35.139583587646484
# epoch: 760 loss: 0.0005629484076052904
# epoch: 760 loss: 2.343499183654785
# epoch: 760 accuracy(object level): 0.9031806361272254
# epoch: 760 accuracy(cluster level max): 0.8899779955991198
# epoch: 760 accuracy(cluster level avg): 0.9021804360872174
# epoch: 770 loss: 35.10744094848633
# epoch: 770 loss: 0.0005631406093016267
# epoch: 770 loss: 2.339838743209839
# epoch: 770 accuracy(object level): 0.9039807961592319
# epoch: 770 accuracy(cluster level max): 0.8911782356471294
# epoch: 770 accuracy(cluster level avg): 0.9019803960792159
# epoch: 780 loss: 35.07076644897461
# epoch: 780 loss: 0.0005623085307888687
# epoch: 780 loss: 2.336188793182373
# epoch: 780 accuracy(object level): 0.9041808361672334
# epoch: 780 accuracy(cluster level max): 0.8907781556311263
# epoch: 780 accuracy(cluster level avg): 0.9031806361272254
# epoch: 790 loss: 35.04586410522461
# epoch: 790 loss: 0.0005623035249300301
# epoch: 790 loss: 2.332589626312256
# epoch: 790 accuracy(object level): 0.904380876175235
# epoch: 790 accuracy(cluster level max): 0.8911782356471294
# epoch: 790 accuracy(cluster level avg): 0.9029805961192239
# epoch: 800 loss: 35.020713806152344
# epoch: 800 loss: 0.0005619849544018507
# epoch: 800 loss: 2.329035520553589
# epoch: 800 accuracy(object level): 0.9045809161832367
# epoch: 800 accuracy(cluster level max): 0.8915783156631326
# epoch: 800 accuracy(cluster level avg): 0.9029805961192239
# epoch: 810 loss: 34.987003326416016
# epoch: 810 loss: 0.000562154920771718
# epoch: 810 loss: 2.325423240661621
# epoch: 810 accuracy(object level): 0.9045809161832367
# epoch: 810 accuracy(cluster level max): 0.8905781156231246
# epoch: 810 accuracy(cluster level avg): 0.9033806761352271
# epoch: 820 loss: 34.96046447753906
# epoch: 820 loss: 0.0005618613213300705
# epoch: 820 loss: 2.321831226348877
# epoch: 820 accuracy(object level): 0.9045809161832367
# epoch: 820 accuracy(cluster level max): 0.8915783156631326
# epoch: 820 accuracy(cluster level avg): 0.9027805561112222
# epoch: 830 loss: 34.930423736572266
# epoch: 830 loss: 0.000561875756829977
# epoch: 830 loss: 2.3183326721191406
# epoch: 830 accuracy(object level): 0.9045809161832367
# epoch: 830 accuracy(cluster level max): 0.8915783156631326
# epoch: 830 accuracy(cluster level avg): 0.9031806361272254
# epoch: 840 loss: 34.90878677368164
# epoch: 840 loss: 0.0005614431574940681
# epoch: 840 loss: 2.3148581981658936
# epoch: 840 accuracy(object level): 0.9045809161832367
# epoch: 840 accuracy(cluster level max): 0.8921784356871374
# epoch: 840 accuracy(cluster level avg): 0.9031806361272254
# epoch: 850 loss: 34.86859893798828
# epoch: 850 loss: 0.0005616562557406723
# epoch: 850 loss: 2.3113670349121094
# epoch: 850 accuracy(object level): 0.9045809161832367
# epoch: 850 accuracy(cluster level max): 0.8917783556711343
# epoch: 850 accuracy(cluster level avg): 0.9033806761352271
# epoch: 860 loss: 34.849857330322266
# epoch: 860 loss: 0.0005621398449875414
# epoch: 860 loss: 2.3079259395599365
# epoch: 860 accuracy(object level): 0.9047809561912382
# epoch: 860 accuracy(cluster level max): 0.8917783556711343
# epoch: 860 accuracy(cluster level avg): 0.9039807961592319
# epoch: 870 loss: 34.81812286376953
# epoch: 870 loss: 0.0005623878678306937
# epoch: 870 loss: 2.304502487182617
# epoch: 870 accuracy(object level): 0.9045809161832367
# epoch: 870 accuracy(cluster level max): 0.8923784756951391
# epoch: 870 accuracy(cluster level avg): 0.9039807961592319
# epoch: 880 loss: 34.8034782409668
# epoch: 880 loss: 0.0005632356042042375
# epoch: 880 loss: 2.3010904788970947
# epoch: 880 accuracy(object level): 0.9049809961992399
# epoch: 880 accuracy(cluster level max): 0.8925785157031406
# epoch: 880 accuracy(cluster level avg): 0.9039807961592319
# epoch: 890 loss: 34.772666931152344
# epoch: 890 loss: 0.0005634820554405451
# epoch: 890 loss: 2.2977147102355957
# epoch: 890 accuracy(object level): 0.9047809561912382
# epoch: 890 accuracy(cluster level max): 0.8925785157031406
# epoch: 890 accuracy(cluster level avg): 0.904380876175235
# epoch: 900 loss: 34.74263000488281
# epoch: 900 loss: 0.0005633828113786876
# epoch: 900 loss: 2.294365406036377
# epoch: 900 accuracy(object level): 0.9047809561912382
# epoch: 900 accuracy(cluster level max): 0.8927785557111422
# epoch: 900 accuracy(cluster level avg): 0.9041808361672334
# epoch: 910 loss: 34.72320556640625
# epoch: 910 loss: 0.0005644999910145998
# epoch: 910 loss: 2.2910397052764893
# epoch: 910 accuracy(object level): 0.9047809561912382
# epoch: 910 accuracy(cluster level max): 0.8923784756951391
# epoch: 910 accuracy(cluster level avg): 0.9041808361672334
# epoch: 920 loss: 34.70207977294922
# epoch: 920 loss: 0.0005645641940645874
# epoch: 920 loss: 2.2877237796783447
# epoch: 920 accuracy(object level): 0.9047809561912382
# epoch: 920 accuracy(cluster level max): 0.8933786757351471
# epoch: 920 accuracy(cluster level avg): 0.9047809561912382
# epoch: 930 loss: 34.679054260253906
# epoch: 930 loss: 0.0005648487131111324
# epoch: 930 loss: 2.2843971252441406
# epoch: 930 accuracy(object level): 0.9045809161832367
# epoch: 930 accuracy(cluster level max): 0.8933786757351471
# epoch: 930 accuracy(cluster level avg): 0.9041808361672334
# epoch: 940 loss: 34.65874099731445
# epoch: 940 loss: 0.0005649621016345918
# epoch: 940 loss: 2.2811079025268555
# epoch: 940 accuracy(object level): 0.9049809961992399
# epoch: 940 accuracy(cluster level max): 0.8929785957191438
# epoch: 940 accuracy(cluster level avg): 0.9049809961992399
# epoch: 950 loss: 34.641448974609375
# epoch: 950 loss: 0.0005652536638081074
# epoch: 950 loss: 2.2778561115264893
# epoch: 950 accuracy(object level): 0.9051810362072414
# epoch: 950 accuracy(cluster level max): 0.8935787157431486
# epoch: 950 accuracy(cluster level avg): 0.9047809561912382
# epoch: 960 loss: 34.6116943359375
# epoch: 960 loss: 0.0005655945278704166
# epoch: 960 loss: 2.274595022201538
# epoch: 960 accuracy(object level): 0.905381076215243
# epoch: 960 accuracy(cluster level max): 0.8933786757351471
# epoch: 960 accuracy(cluster level avg): 0.9047809561912382
# epoch: 970 loss: 34.59320068359375
# epoch: 970 loss: 0.0005656948196701705
# epoch: 970 loss: 2.2713351249694824
# epoch: 970 accuracy(object level): 0.905381076215243
# epoch: 970 accuracy(cluster level max): 0.8935787157431486
# epoch: 970 accuracy(cluster level avg): 0.9049809961992399
# epoch: 980 loss: 34.571102142333984
# epoch: 980 loss: 0.0005656710127368569
# epoch: 980 loss: 2.268125295639038
# epoch: 980 accuracy(object level): 0.9047809561912382
# epoch: 980 accuracy(cluster level max): 0.8943788757751551
# epoch: 980 accuracy(cluster level avg): 0.9047809561912382
# epoch: 990 loss: 34.54713821411133
# epoch: 990 loss: 0.0005659356247633696
# epoch: 990 loss: 2.2649312019348145
# epoch: 990 accuracy(object level): 0.9047809561912382
# epoch: 990 accuracy(cluster level max): 0.8939787957591518
# epoch: 990 accuracy(cluster level avg): 0.9047809561912382
# epoch: 1000 loss: 34.53178787231445
# epoch: 1000 loss: 0.0005663148476742208
# epoch: 1000 loss: 2.2618391513824463
# epoch: 1000 accuracy(object level): 0.9049809961992399
# epoch: 1000 accuracy(cluster level max): 0.8947789557911582
# epoch: 1000 accuracy(cluster level avg): 0.9045809161832367
# epoch: 1010 loss: 34.51369857788086
# epoch: 1010 loss: 0.0005671435501426458
# epoch: 1010 loss: 2.258761167526245
# epoch: 1010 accuracy(object level): 0.9047809561912382
# epoch: 1010 accuracy(cluster level max): 0.8945789157831566
# epoch: 1010 accuracy(cluster level avg): 0.904380876175235
# epoch: 1020 loss: 34.48893356323242
# epoch: 1020 loss: 0.0005677726003341377
# epoch: 1020 loss: 2.255601167678833
# epoch: 1020 accuracy(object level): 0.905381076215243
# epoch: 1020 accuracy(cluster level max): 0.8953790758151631
# epoch: 1020 accuracy(cluster level avg): 0.9045809161832367
# epoch: 1030 loss: 34.4762077331543
# epoch: 1030 loss: 0.0005681494367308915
# epoch: 1030 loss: 2.2525031566619873
# epoch: 1030 accuracy(object level): 0.905381076215243
# epoch: 1030 accuracy(cluster level max): 0.8959791958391679
# epoch: 1030 accuracy(cluster level avg): 0.9047809561912382
# epoch: 1040 loss: 34.44963455200195
# epoch: 1040 loss: 0.0005683997878804803
# epoch: 1040 loss: 2.249424457550049
# epoch: 1040 accuracy(object level): 0.9055811162232447
# epoch: 1040 accuracy(cluster level max): 0.8951790358071614
# epoch: 1040 accuracy(cluster level avg): 0.9051810362072414
# epoch: 1050 loss: 34.43370819091797
# epoch: 1050 loss: 0.0005694935098290443
# epoch: 1050 loss: 2.2464065551757812
# epoch: 1050 accuracy(object level): 0.9055811162232447
# epoch: 1050 accuracy(cluster level max): 0.8957791558311662
# epoch: 1050 accuracy(cluster level avg): 0.9051810362072414
# epoch: 1060 loss: 34.42255783081055
# epoch: 1060 loss: 0.0005696919397450984
# epoch: 1060 loss: 2.2433536052703857
# epoch: 1060 accuracy(object level): 0.9057811562312462
# epoch: 1060 accuracy(cluster level max): 0.8961792358471694
# epoch: 1060 accuracy(cluster level avg): 0.9049809961992399
# epoch: 1070 loss: 34.396934509277344
# epoch: 1070 loss: 0.000569911499042064
# epoch: 1070 loss: 2.240321397781372
# epoch: 1070 accuracy(object level): 0.9057811562312462
# epoch: 1070 accuracy(cluster level max): 0.8965793158631726
# epoch: 1070 accuracy(cluster level avg): 0.9049809961992399
# epoch: 1080 loss: 34.377220153808594
# epoch: 1080 loss: 0.0005702147027477622
# epoch: 1080 loss: 2.2373440265655518
# epoch: 1080 accuracy(object level): 0.9057811562312462
# epoch: 1080 accuracy(cluster level max): 0.8961792358471694
# epoch: 1080 accuracy(cluster level avg): 0.9051810362072414
# epoch: 1090 loss: 34.365230560302734
# epoch: 1090 loss: 0.0005709666293114424
# epoch: 1090 loss: 2.2344043254852295
# epoch: 1090 accuracy(object level): 0.9059811962392479
# epoch: 1090 accuracy(cluster level max): 0.8969793958791759
# epoch: 1090 accuracy(cluster level avg): 0.905381076215243
# epoch: 1100 loss: 34.34461212158203
# epoch: 1100 loss: 0.0005719641339965165
# epoch: 1100 loss: 2.2314586639404297
# epoch: 1100 accuracy(object level): 0.9059811962392479
# epoch: 1100 accuracy(cluster level max): 0.8965793158631726
# epoch: 1100 accuracy(cluster level avg): 0.905381076215243
# epoch: 1110 loss: 34.32417297363281
# epoch: 1110 loss: 0.0005724432412534952
# epoch: 1110 loss: 2.228541135787964
# epoch: 1110 accuracy(object level): 0.9059811962392479
# epoch: 1110 accuracy(cluster level max): 0.8965793158631726
# epoch: 1110 accuracy(cluster level avg): 0.9055811162232447
# epoch: 1120 loss: 34.312522888183594
# epoch: 1120 loss: 0.0005724886432290077
# epoch: 1120 loss: 2.2256622314453125
# epoch: 1120 accuracy(object level): 0.9059811962392479
# epoch: 1120 accuracy(cluster level max): 0.8967793558711742
# epoch: 1120 accuracy(cluster level avg): 0.905381076215243
# epoch: 1130 loss: 34.2968635559082
# epoch: 1130 loss: 0.0005726306117139757
# epoch: 1130 loss: 2.22275972366333
# epoch: 1130 accuracy(object level): 0.9057811562312462
# epoch: 1130 accuracy(cluster level max): 0.8973794758951791
# epoch: 1130 accuracy(cluster level avg): 0.905381076215243
# epoch: 1140 loss: 34.27957534790039
# epoch: 1140 loss: 0.0005725374212488532
# epoch: 1140 loss: 2.219905138015747
# epoch: 1140 accuracy(object level): 0.9057811562312462
# epoch: 1140 accuracy(cluster level max): 0.8983796759351871
# epoch: 1140 accuracy(cluster level avg): 0.9051810362072414
# epoch: 1150 loss: 34.26740264892578
# epoch: 1150 loss: 0.0005729335825890303
# epoch: 1150 loss: 2.2170863151550293
# epoch: 1150 accuracy(object level): 0.9055811162232447
# epoch: 1150 accuracy(cluster level max): 0.8969793958791759
# epoch: 1150 accuracy(cluster level avg): 0.9049809961992399
# epoch: 1160 loss: 34.252681732177734
# epoch: 1160 loss: 0.0005728795076720417
# epoch: 1160 loss: 2.2142646312713623
# epoch: 1160 accuracy(object level): 0.905381076215243
# epoch: 1160 accuracy(cluster level max): 0.8975795159031806
# epoch: 1160 accuracy(cluster level avg): 0.9049809961992399
# epoch: 1170 loss: 34.235294342041016
# epoch: 1170 loss: 0.0005730421398766339
# epoch: 1170 loss: 2.211491107940674
# epoch: 1170 accuracy(object level): 0.905381076215243
# epoch: 1170 accuracy(cluster level max): 0.8977795559111822
# epoch: 1170 accuracy(cluster level avg): 0.9055811162232447
# epoch: 1180 loss: 34.2207145690918
# epoch: 1180 loss: 0.0005740638007409871
# epoch: 1180 loss: 2.208740711212158
# epoch: 1180 accuracy(object level): 0.905381076215243
# epoch: 1180 accuracy(cluster level max): 0.8985797159431886
# epoch: 1180 accuracy(cluster level avg): 0.9057811562312462
# epoch: 1190 loss: 34.20328140258789
# epoch: 1190 loss: 0.0005744292866438627
# epoch: 1190 loss: 2.2060000896453857
# epoch: 1190 accuracy(object level): 0.9055811162232447
# epoch: 1190 accuracy(cluster level max): 0.8979795959191839
# epoch: 1190 accuracy(cluster level avg): 0.9051810362072414
# epoch: 1200 loss: 34.18685531616211
# epoch: 1200 loss: 0.0005748241674154997
# epoch: 1200 loss: 2.2032387256622314
# epoch: 1200 accuracy(object level): 0.9055811162232447
# epoch: 1200 accuracy(cluster level max): 0.8977795559111822
# epoch: 1200 accuracy(cluster level avg): 0.905381076215243
# epoch: 1210 loss: 34.18338394165039
# epoch: 1210 loss: 0.000575603567995131
# epoch: 1210 loss: 2.2005107402801514
# epoch: 1210 accuracy(object level): 0.9055811162232447
# epoch: 1210 accuracy(cluster level max): 0.8981796359271854
# epoch: 1210 accuracy(cluster level avg): 0.9047809561912382
# epoch: 1220 loss: 34.17121887207031
# epoch: 1220 loss: 0.0005754667799919844
# epoch: 1220 loss: 2.197814464569092
# epoch: 1220 accuracy(object level): 0.9055811162232447
# epoch: 1220 accuracy(cluster level max): 0.8983796759351871
# epoch: 1220 accuracy(cluster level avg): 0.9055811162232447
# epoch: 1230 loss: 34.15302276611328
# epoch: 1230 loss: 0.000575884070713073
# epoch: 1230 loss: 2.1951351165771484
# epoch: 1230 accuracy(object level): 0.9055811162232447
# epoch: 1230 accuracy(cluster level max): 0.8985797159431886
# epoch: 1230 accuracy(cluster level avg): 0.9057811562312462
# epoch: 1240 loss: 34.13478088378906
# epoch: 1240 loss: 0.0005764866946265101
# epoch: 1240 loss: 2.192467451095581
# epoch: 1240 accuracy(object level): 0.9055811162232447
# epoch: 1240 accuracy(cluster level max): 0.8977795559111822
# epoch: 1240 accuracy(cluster level avg): 0.9057811562312462
# epoch: 1250 loss: 34.12761688232422
# epoch: 1250 loss: 0.0005772333242930472
# epoch: 1250 loss: 2.1898787021636963
# epoch: 1250 accuracy(object level): 0.905381076215243
# epoch: 1250 accuracy(cluster level max): 0.8983796759351871
# epoch: 1250 accuracy(cluster level avg): 0.9055811162232447
# epoch: 1260 loss: 34.11525344848633
# epoch: 1260 loss: 0.0005777762271463871
# epoch: 1260 loss: 2.1872360706329346
# epoch: 1260 accuracy(object level): 0.9055811162232447
# epoch: 1260 accuracy(cluster level max): 0.8983796759351871
# epoch: 1260 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1270 loss: 34.098148345947266
# epoch: 1270 loss: 0.0005780039937235415
# epoch: 1270 loss: 2.1846323013305664
# epoch: 1270 accuracy(object level): 0.9057811562312462
# epoch: 1270 accuracy(cluster level max): 0.8993798759751951
# epoch: 1270 accuracy(cluster level avg): 0.9057811562312462
# epoch: 1280 loss: 34.097633361816406
# epoch: 1280 loss: 0.0005777314654551446
# epoch: 1280 loss: 2.182076930999756
# epoch: 1280 accuracy(object level): 0.9059811962392479
# epoch: 1280 accuracy(cluster level max): 0.8985797159431886
# epoch: 1280 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1290 loss: 34.07343673706055
# epoch: 1290 loss: 0.0005778660997748375
# epoch: 1290 loss: 2.179529905319214
# epoch: 1290 accuracy(object level): 0.9059811962392479
# epoch: 1290 accuracy(cluster level max): 0.8991798359671934
# epoch: 1290 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1300 loss: 34.0642204284668
# epoch: 1300 loss: 0.0005781761719845235
# epoch: 1300 loss: 2.177027463912964
# epoch: 1300 accuracy(object level): 0.9059811962392479
# epoch: 1300 accuracy(cluster level max): 0.8999799959991999
# epoch: 1300 accuracy(cluster level avg): 0.906381276255251
# epoch: 1310 loss: 34.050392150878906
# epoch: 1310 loss: 0.0005786494584754109
# epoch: 1310 loss: 2.1745107173919678
# epoch: 1310 accuracy(object level): 0.9059811962392479
# epoch: 1310 accuracy(cluster level max): 0.8993798759751951
# epoch: 1310 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1320 loss: 34.03962707519531
# epoch: 1320 loss: 0.0005794427124783397
# epoch: 1320 loss: 2.172041893005371
# epoch: 1320 accuracy(object level): 0.9061812362472494
# epoch: 1320 accuracy(cluster level max): 0.8989797959591919
# epoch: 1320 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1330 loss: 34.032772064208984
# epoch: 1330 loss: 0.0005791789735667408
# epoch: 1330 loss: 2.1695971488952637
# epoch: 1330 accuracy(object level): 0.9059811962392479
# epoch: 1330 accuracy(cluster level max): 0.8999799959991999
# epoch: 1330 accuracy(cluster level avg): 0.906381276255251
# epoch: 1340 loss: 34.023765563964844
# epoch: 1340 loss: 0.0005793895106762648
# epoch: 1340 loss: 2.1671640872955322
# epoch: 1340 accuracy(object level): 0.9057811562312462
# epoch: 1340 accuracy(cluster level max): 0.8991798359671934
# epoch: 1340 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1350 loss: 34.005924224853516
# epoch: 1350 loss: 0.0005787081317976117
# epoch: 1350 loss: 2.164743423461914
# epoch: 1350 accuracy(object level): 0.9059811962392479
# epoch: 1350 accuracy(cluster level max): 0.8997799559911982
# epoch: 1350 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1360 loss: 34.008182525634766
# epoch: 1360 loss: 0.0005792902666144073
# epoch: 1360 loss: 2.1623528003692627
# epoch: 1360 accuracy(object level): 0.9059811962392479
# epoch: 1360 accuracy(cluster level max): 0.9005801160232046
# epoch: 1360 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1370 loss: 33.98542404174805
# epoch: 1370 loss: 0.0005791273433715105
# epoch: 1370 loss: 2.159965753555298
# epoch: 1370 accuracy(object level): 0.9061812362472494
# epoch: 1370 accuracy(cluster level max): 0.8997799559911982
# epoch: 1370 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1380 loss: 33.972843170166016
# epoch: 1380 loss: 0.0005788276321254671
# epoch: 1380 loss: 2.157588005065918
# epoch: 1380 accuracy(object level): 0.9061812362472494
# epoch: 1380 accuracy(cluster level max): 0.8999799959991999
# epoch: 1380 accuracy(cluster level avg): 0.906381276255251
# epoch: 1390 loss: 33.96565246582031
# epoch: 1390 loss: 0.0005792477168142796
# epoch: 1390 loss: 2.155252695083618
# epoch: 1390 accuracy(object level): 0.906381276255251
# epoch: 1390 accuracy(cluster level max): 0.9005801160232046
# epoch: 1390 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1400 loss: 33.95901107788086
# epoch: 1400 loss: 0.0005800022045150399
# epoch: 1400 loss: 2.1529548168182373
# epoch: 1400 accuracy(object level): 0.906381276255251
# epoch: 1400 accuracy(cluster level max): 0.8999799959991999
# epoch: 1400 accuracy(cluster level avg): 0.906381276255251
# epoch: 1410 loss: 33.94539260864258
# epoch: 1410 loss: 0.0005797609919682145
# epoch: 1410 loss: 2.1506664752960205
# epoch: 1410 accuracy(object level): 0.906381276255251
# epoch: 1410 accuracy(cluster level max): 0.9001800360072014
# epoch: 1410 accuracy(cluster level avg): 0.906381276255251
# epoch: 1420 loss: 33.94001770019531
# epoch: 1420 loss: 0.0005793888703919947
# epoch: 1420 loss: 2.1483876705169678
# epoch: 1420 accuracy(object level): 0.9061812362472494
# epoch: 1420 accuracy(cluster level max): 0.9003800760152031
# epoch: 1420 accuracy(cluster level avg): 0.906381276255251
# epoch: 1430 loss: 33.92177963256836
# epoch: 1430 loss: 0.0005797278136014938
# epoch: 1430 loss: 2.1461193561553955
# epoch: 1430 accuracy(object level): 0.906381276255251
# epoch: 1430 accuracy(cluster level max): 0.9007801560312062
# epoch: 1430 accuracy(cluster level avg): 0.906381276255251
# epoch: 1440 loss: 33.92151641845703
# epoch: 1440 loss: 0.0005798513302579522
# epoch: 1440 loss: 2.1438958644866943
# epoch: 1440 accuracy(object level): 0.906381276255251
# epoch: 1440 accuracy(cluster level max): 0.9003800760152031
# epoch: 1440 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1450 loss: 33.90779495239258
# epoch: 1450 loss: 0.0005799775244668126
# epoch: 1450 loss: 2.1417088508605957
# epoch: 1450 accuracy(object level): 0.9065813162632527
# epoch: 1450 accuracy(cluster level max): 0.9009801960392079
# epoch: 1450 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1460 loss: 33.896907806396484
# epoch: 1460 loss: 0.0005798933561891317
# epoch: 1460 loss: 2.1395301818847656
# epoch: 1460 accuracy(object level): 0.9067813562712542
# epoch: 1460 accuracy(cluster level max): 0.9003800760152031
# epoch: 1460 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1470 loss: 33.893253326416016
# epoch: 1470 loss: 0.00057990662753582
# epoch: 1470 loss: 2.1373450756073
# epoch: 1470 accuracy(object level): 0.9067813562712542
# epoch: 1470 accuracy(cluster level max): 0.9009801960392079
# epoch: 1470 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1480 loss: 33.8864631652832
# epoch: 1480 loss: 0.000580094289034605
# epoch: 1480 loss: 2.1351675987243652
# epoch: 1480 accuracy(object level): 0.9065813162632527
# epoch: 1480 accuracy(cluster level max): 0.9007801560312062
# epoch: 1480 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1490 loss: 33.87968444824219
# epoch: 1490 loss: 0.000579789571929723
# epoch: 1490 loss: 2.1330301761627197
# epoch: 1490 accuracy(object level): 0.9065813162632527
# epoch: 1490 accuracy(cluster level max): 0.9011802360472094
# epoch: 1490 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1500 loss: 33.863197326660156
# epoch: 1500 loss: 0.0005800488870590925
# epoch: 1500 loss: 2.1309001445770264
# epoch: 1500 accuracy(object level): 0.9067813562712542
# epoch: 1500 accuracy(cluster level max): 0.9009801960392079
# epoch: 1500 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1510 loss: 33.85419464111328
# epoch: 1510 loss: 0.0005802249652333558
# epoch: 1510 loss: 2.1287825107574463
# epoch: 1510 accuracy(object level): 0.9067813562712542
# epoch: 1510 accuracy(cluster level max): 0.9013802760552111
# epoch: 1510 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1520 loss: 33.845436096191406
# epoch: 1520 loss: 0.0005806550034321845
# epoch: 1520 loss: 2.1266822814941406
# epoch: 1520 accuracy(object level): 0.9067813562712542
# epoch: 1520 accuracy(cluster level max): 0.9009801960392079
# epoch: 1520 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1530 loss: 33.84141159057617
# epoch: 1530 loss: 0.0005812373710796237
# epoch: 1530 loss: 2.124617576599121
# epoch: 1530 accuracy(object level): 0.9065813162632527
# epoch: 1530 accuracy(cluster level max): 0.9009801960392079
# epoch: 1530 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1540 loss: 33.83088302612305
# epoch: 1540 loss: 0.0005809558788314462
# epoch: 1540 loss: 2.122575521469116
# epoch: 1540 accuracy(object level): 0.9065813162632527
# epoch: 1540 accuracy(cluster level max): 0.9009801960392079
# epoch: 1540 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1550 loss: 33.82243347167969
# epoch: 1550 loss: 0.0005816466291435063
# epoch: 1550 loss: 2.1205387115478516
# epoch: 1550 accuracy(object level): 0.9065813162632527
# epoch: 1550 accuracy(cluster level max): 0.9017803560712142
# epoch: 1550 accuracy(cluster level avg): 0.906381276255251
# epoch: 1560 loss: 33.81464767456055
# epoch: 1560 loss: 0.0005818805657327175
# epoch: 1560 loss: 2.118522882461548
# epoch: 1560 accuracy(object level): 0.906381276255251
# epoch: 1560 accuracy(cluster level max): 0.9013802760552111
# epoch: 1560 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1570 loss: 33.804901123046875
# epoch: 1570 loss: 0.0005821187514811754
# epoch: 1570 loss: 2.1165518760681152
# epoch: 1570 accuracy(object level): 0.906381276255251
# epoch: 1570 accuracy(cluster level max): 0.9011802360472094
# epoch: 1570 accuracy(cluster level avg): 0.906381276255251
# epoch: 1580 loss: 33.80005645751953
# epoch: 1580 loss: 0.0005824099644087255
# epoch: 1580 loss: 2.114591598510742
# epoch: 1580 accuracy(object level): 0.906381276255251
# epoch: 1580 accuracy(cluster level max): 0.9011802360472094
# epoch: 1580 accuracy(cluster level avg): 0.906381276255251
# epoch: 1590 loss: 33.79111099243164
# epoch: 1590 loss: 0.000582951819524169
# epoch: 1590 loss: 2.1126585006713867
# epoch: 1590 accuracy(object level): 0.9065813162632527
# epoch: 1590 accuracy(cluster level max): 0.9011802360472094
# epoch: 1590 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1600 loss: 33.78815841674805
# epoch: 1600 loss: 0.0005831501912325621
# epoch: 1600 loss: 2.1107394695281982
# epoch: 1600 accuracy(object level): 0.9065813162632527
# epoch: 1600 accuracy(cluster level max): 0.9011802360472094
# epoch: 1600 accuracy(cluster level avg): 0.906381276255251
# epoch: 1610 loss: 33.78159713745117
# epoch: 1610 loss: 0.0005829815054312348
# epoch: 1610 loss: 2.1088316440582275
# epoch: 1610 accuracy(object level): 0.9065813162632527
# epoch: 1610 accuracy(cluster level max): 0.9015803160632127
# epoch: 1610 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1620 loss: 33.7667236328125
# epoch: 1620 loss: 0.0005823557730764151
# epoch: 1620 loss: 2.106919765472412
# epoch: 1620 accuracy(object level): 0.9065813162632527
# epoch: 1620 accuracy(cluster level max): 0.9013802760552111
# epoch: 1620 accuracy(cluster level avg): 0.906381276255251
# epoch: 1630 loss: 33.76377868652344
# epoch: 1630 loss: 0.0005824837135151029
# epoch: 1630 loss: 2.105062246322632
# epoch: 1630 accuracy(object level): 0.9065813162632527
# epoch: 1630 accuracy(cluster level max): 0.9013802760552111
# epoch: 1630 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1640 loss: 33.75283432006836
# epoch: 1640 loss: 0.000582784996367991
# epoch: 1640 loss: 2.1032071113586426
# epoch: 1640 accuracy(object level): 0.9067813562712542
# epoch: 1640 accuracy(cluster level max): 0.9013802760552111
# epoch: 1640 accuracy(cluster level avg): 0.906381276255251
# epoch: 1650 loss: 33.746246337890625
# epoch: 1650 loss: 0.0005831409944221377
# epoch: 1650 loss: 2.1013691425323486
# epoch: 1650 accuracy(object level): 0.9067813562712542
# epoch: 1650 accuracy(cluster level max): 0.9005801160232046
# epoch: 1650 accuracy(cluster level avg): 0.906381276255251
# epoch: 1660 loss: 33.740577697753906
# epoch: 1660 loss: 0.0005833992618136108
# epoch: 1660 loss: 2.099522590637207
# epoch: 1660 accuracy(object level): 0.9067813562712542
# epoch: 1660 accuracy(cluster level max): 0.9009801960392079
# epoch: 1660 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1670 loss: 33.7405891418457
# epoch: 1670 loss: 0.0005840325611643493
# epoch: 1670 loss: 2.0977206230163574
# epoch: 1670 accuracy(object level): 0.9067813562712542
# epoch: 1670 accuracy(cluster level max): 0.9015803160632127
# epoch: 1670 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1680 loss: 33.72951126098633
# epoch: 1680 loss: 0.0005840397207066417
# epoch: 1680 loss: 2.095921277999878
# epoch: 1680 accuracy(object level): 0.9069813962792559
# epoch: 1680 accuracy(cluster level max): 0.9017803560712142
# epoch: 1680 accuracy(cluster level avg): 0.906381276255251
# epoch: 1690 loss: 33.72048568725586
# epoch: 1690 loss: 0.000584054971113801
# epoch: 1690 loss: 2.094162702560425
# epoch: 1690 accuracy(object level): 0.9071814362872574
# epoch: 1690 accuracy(cluster level max): 0.9013802760552111
# epoch: 1690 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1700 loss: 33.7127799987793
# epoch: 1700 loss: 0.0005835944321006536
# epoch: 1700 loss: 2.092414379119873
# epoch: 1700 accuracy(object level): 0.9071814362872574
# epoch: 1700 accuracy(cluster level max): 0.9017803560712142
# epoch: 1700 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1710 loss: 33.71515655517578
# epoch: 1710 loss: 0.0005837627686560154
# epoch: 1710 loss: 2.0906665325164795
# epoch: 1710 accuracy(object level): 0.9071814362872574
# epoch: 1710 accuracy(cluster level max): 0.9017803560712142
# epoch: 1710 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1720 loss: 33.70590591430664
# epoch: 1720 loss: 0.0005832832539454103
# epoch: 1720 loss: 2.088930368423462
# epoch: 1720 accuracy(object level): 0.9071814362872574
# epoch: 1720 accuracy(cluster level max): 0.9023804760952191
# epoch: 1720 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1730 loss: 33.703433990478516
# epoch: 1730 loss: 0.0005836962955072522
# epoch: 1730 loss: 2.087226152420044
# epoch: 1730 accuracy(object level): 0.9071814362872574
# epoch: 1730 accuracy(cluster level max): 0.9015803160632127
# epoch: 1730 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1740 loss: 33.7022819519043
# epoch: 1740 loss: 0.0005834895418956876
# epoch: 1740 loss: 2.085510492324829
# epoch: 1740 accuracy(object level): 0.9069813962792559
# epoch: 1740 accuracy(cluster level max): 0.9017803560712142
# epoch: 1740 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1750 loss: 33.68745040893555
# epoch: 1750 loss: 0.0005834008334204555
# epoch: 1750 loss: 2.083843946456909
# epoch: 1750 accuracy(object level): 0.9065813162632527
# epoch: 1750 accuracy(cluster level max): 0.9019803960792159
# epoch: 1750 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1760 loss: 33.68212127685547
# epoch: 1760 loss: 0.000583226908929646
# epoch: 1760 loss: 2.082195520401001
# epoch: 1760 accuracy(object level): 0.9065813162632527
# epoch: 1760 accuracy(cluster level max): 0.9023804760952191
# epoch: 1760 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1770 loss: 33.67511749267578
# epoch: 1770 loss: 0.0005837493226863444
# epoch: 1770 loss: 2.0805511474609375
# epoch: 1770 accuracy(object level): 0.906381276255251
# epoch: 1770 accuracy(cluster level max): 0.9021804360872174
# epoch: 1770 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1780 loss: 33.669593811035156
# epoch: 1780 loss: 0.000583887449465692
# epoch: 1780 loss: 2.0789573192596436
# epoch: 1780 accuracy(object level): 0.906381276255251
# epoch: 1780 accuracy(cluster level max): 0.9017803560712142
# epoch: 1780 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1790 loss: 33.65970230102539
# epoch: 1790 loss: 0.0005842767423018813
# epoch: 1790 loss: 2.0773561000823975
# epoch: 1790 accuracy(object level): 0.906381276255251
# epoch: 1790 accuracy(cluster level max): 0.9023804760952191
# epoch: 1790 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1800 loss: 33.662322998046875
# epoch: 1800 loss: 0.0005850078305229545
# epoch: 1800 loss: 2.0757927894592285
# epoch: 1800 accuracy(object level): 0.9067813562712542
# epoch: 1800 accuracy(cluster level max): 0.9023804760952191
# epoch: 1800 accuracy(cluster level avg): 0.906381276255251
# epoch: 1810 loss: 33.66029739379883
# epoch: 1810 loss: 0.0005854305345565081
# epoch: 1810 loss: 2.07420015335083
# epoch: 1810 accuracy(object level): 0.9067813562712542
# epoch: 1810 accuracy(cluster level max): 0.9033806761352271
# epoch: 1810 accuracy(cluster level avg): 0.906381276255251
# epoch: 1820 loss: 33.65522384643555
# epoch: 1820 loss: 0.0005844947881996632
# epoch: 1820 loss: 2.072619676589966
# epoch: 1820 accuracy(object level): 0.9067813562712542
# epoch: 1820 accuracy(cluster level max): 0.9023804760952191
# epoch: 1820 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1830 loss: 33.6517333984375
# epoch: 1830 loss: 0.0005846393178217113
# epoch: 1830 loss: 2.071052074432373
# epoch: 1830 accuracy(object level): 0.9067813562712542
# epoch: 1830 accuracy(cluster level max): 0.9025805161032207
# epoch: 1830 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1840 loss: 33.63882827758789
# epoch: 1840 loss: 0.000584467314183712
# epoch: 1840 loss: 2.069523811340332
# epoch: 1840 accuracy(object level): 0.9069813962792559
# epoch: 1840 accuracy(cluster level max): 0.9027805561112222
# epoch: 1840 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1850 loss: 33.63542938232422
# epoch: 1850 loss: 0.0005844278493896127
# epoch: 1850 loss: 2.068028688430786
# epoch: 1850 accuracy(object level): 0.9069813962792559
# epoch: 1850 accuracy(cluster level max): 0.9027805561112222
# epoch: 1850 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1860 loss: 33.62827682495117
# epoch: 1860 loss: 0.0005840394296683371
# epoch: 1860 loss: 2.0665621757507324
# epoch: 1860 accuracy(object level): 0.9069813962792559
# epoch: 1860 accuracy(cluster level max): 0.9021804360872174
# epoch: 1860 accuracy(cluster level avg): 0.906381276255251
# epoch: 1870 loss: 33.62434005737305
# epoch: 1870 loss: 0.000583635875955224
# epoch: 1870 loss: 2.0650899410247803
# epoch: 1870 accuracy(object level): 0.9069813962792559
# epoch: 1870 accuracy(cluster level max): 0.9025805161032207
# epoch: 1870 accuracy(cluster level avg): 0.906381276255251
# epoch: 1880 loss: 33.61684036254883
# epoch: 1880 loss: 0.0005832415772601962
# epoch: 1880 loss: 2.063626766204834
# epoch: 1880 accuracy(object level): 0.9069813962792559
# epoch: 1880 accuracy(cluster level max): 0.9025805161032207
# epoch: 1880 accuracy(cluster level avg): 0.906381276255251
# epoch: 1890 loss: 33.61664962768555
# epoch: 1890 loss: 0.0005831476300954819
# epoch: 1890 loss: 2.0621721744537354
# epoch: 1890 accuracy(object level): 0.9067813562712542
# epoch: 1890 accuracy(cluster level max): 0.9025805161032207
# epoch: 1890 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1900 loss: 33.605777740478516
# epoch: 1900 loss: 0.0005831937305629253
# epoch: 1900 loss: 2.0607478618621826
# epoch: 1900 accuracy(object level): 0.9067813562712542
# epoch: 1900 accuracy(cluster level max): 0.9027805561112222
# epoch: 1900 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1910 loss: 33.602352142333984
# epoch: 1910 loss: 0.000582993496209383
# epoch: 1910 loss: 2.0593295097351074
# epoch: 1910 accuracy(object level): 0.9067813562712542
# epoch: 1910 accuracy(cluster level max): 0.9025805161032207
# epoch: 1910 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1920 loss: 33.59389877319336
# epoch: 1920 loss: 0.0005829824949614704
# epoch: 1920 loss: 2.0579257011413574
# epoch: 1920 accuracy(object level): 0.9065813162632527
# epoch: 1920 accuracy(cluster level max): 0.9031806361272254
# epoch: 1920 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1930 loss: 33.59083557128906
# epoch: 1930 loss: 0.0005830644513480365
# epoch: 1930 loss: 2.0565524101257324
# epoch: 1930 accuracy(object level): 0.9065813162632527
# epoch: 1930 accuracy(cluster level max): 0.9029805961192239
# epoch: 1930 accuracy(cluster level avg): 0.906381276255251
# epoch: 1940 loss: 33.58734130859375
# epoch: 1940 loss: 0.0005829442525282502
# epoch: 1940 loss: 2.055175304412842
# epoch: 1940 accuracy(object level): 0.9065813162632527
# epoch: 1940 accuracy(cluster level max): 0.9023804760952191
# epoch: 1940 accuracy(cluster level avg): 0.906381276255251
# epoch: 1950 loss: 33.58822250366211
# epoch: 1950 loss: 0.0005830768495798111
# epoch: 1950 loss: 2.0538063049316406
# epoch: 1950 accuracy(object level): 0.9065813162632527
# epoch: 1950 accuracy(cluster level max): 0.9025805161032207
# epoch: 1950 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1960 loss: 33.58102798461914
# epoch: 1960 loss: 0.0005830726586282253
# epoch: 1960 loss: 2.05242919921875
# epoch: 1960 accuracy(object level): 0.9065813162632527
# epoch: 1960 accuracy(cluster level max): 0.9031806361272254
# epoch: 1960 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1970 loss: 33.57631301879883
# epoch: 1970 loss: 0.0005830753361806273
# epoch: 1970 loss: 2.0510952472686768
# epoch: 1970 accuracy(object level): 0.9065813162632527
# epoch: 1970 accuracy(cluster level max): 0.9031806361272254
# epoch: 1970 accuracy(cluster level avg): 0.906381276255251
# epoch: 1980 loss: 33.5705451965332
# epoch: 1980 loss: 0.0005833279574289918
# epoch: 1980 loss: 2.0497820377349854
# epoch: 1980 accuracy(object level): 0.9065813162632527
# epoch: 1980 accuracy(cluster level max): 0.9029805961192239
# epoch: 1980 accuracy(cluster level avg): 0.906381276255251
# epoch: 1990 loss: 33.56440353393555
# epoch: 1990 loss: 0.0005837166681885719
# epoch: 1990 loss: 2.048473834991455
# epoch: 1990 accuracy(object level): 0.9065813162632527
# epoch: 1990 accuracy(cluster level max): 0.9027805561112222
# epoch: 1990 accuracy(cluster level avg): 0.9065813162632527
# Training overall net. Done!

# %%
import scipy.io
if False:
    scipy.io.savemat('trial_tf_workplace', 
                     {'monitor_q_zxl':monitor_q_zxl})
