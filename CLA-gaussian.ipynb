# %%
import numpy as np
import deep_laa_support as dls
import random
import sys
import tensorflow as tf
from sklearn.cluster import KMeans

# convert data from .mat to .npz
# in_file = "feature_31_L"
# dls.convert_mat_to_one_hot_npz(in_file)
# print('file ' + in_file + '.npz ' 'saved.')

# read data
filename = "feature_rotten_tomatoes"
data_all = np.load(filename +'.npz')
print('file ' + filename + '.npz ' 'loaded.')
user_labels = data_all['user_labels']
true_labels = data_all['true_labels']
category_size = data_all['category_num']
source_num = data_all['source_num']
feature = data_all['feature']
_, feature_size = np.shape(feature)
n_samples, _ = np.shape(true_labels)

#================= basic parameters =====================
# define batch size (use all samples in one batch)
batch_size = n_samples # n_samples
cluster_num = 100
T = 1 # mc_sampling_times

#================= encoder q(y|l) and q(h|x) =====================
with tf.name_scope('encoder'):
    #================= q(y|l) =====================
    # define input l (source label vectors)
    input_size = source_num * category_size
    with tf.variable_scope('q_yl'):
        l = tf.placeholder(dtype=tf.float32, shape=[batch_size, input_size], name='l_input')
        pi_yl, weights_yl, biases_yl = dls.LAA_encoder(l, batch_size, source_num, category_size)
    # loss: cross entropy between y_classifier and y_target for pre-training classifier
    with tf.variable_scope('q_yl'):
        pi_yl_target = tf.placeholder(dtype=tf.float32, shape=[batch_size, category_size], name='pi_yl_target')
        loss_yl = dls.LAA_loss_classifier(pi_yl, pi_yl_target)
    # optimizier
    learning_rate_yl = 0.01
    optimizer_pre_train_yl = tf.train.AdamOptimizer(learning_rate=learning_rate_yl).minimize(loss_yl)

    #================= q(h|x) =====================
    h1_size_encoder = int(np.floor(feature_size/2.0))
    h2_size_encoder = int(np.floor(feature_size/10.0))
    embedding_size = int(np.floor(feature_size/40.0))
    h1_size_decoder = int(np.floor(feature_size/10.0))
    h2_size_decoder = int(np.floor(feature_size/2.0))
    # h1_size_encoder = int(np.floor(feature_size/2.0))
    # h2_size_encoder = int(np.floor(feature_size/4.0))
    # embedding_size = int(np.floor(feature_size/8.0))
    # h1_size_decoder = int(np.floor(feature_size/4.0))
    # h2_size_decoder = int(np.floor(feature_size/2.0))
    with tf.variable_scope('q_hx'):
        x = tf.placeholder(dtype=tf.float32, shape=[batch_size, feature_size], name='x_input')
        # mu_hx[batch_size, embedding_size]
        # sigma_hx[batch_size, embedding_size]
        with tf.variable_scope('feature_encoder_h1'):
            _h1_encoder, w1_encoder, b1_encoder = dls.full_connect_relu_BN(x, [feature_size, h1_size_encoder])
        with tf.variable_scope('feature_encoder_h2'):
            _h2_encoder, w2_encoder, b2_encoder = dls.full_connect_relu_BN(_h1_encoder, [h1_size_encoder, h2_size_encoder])
        with tf.variable_scope('feature_encoder_mu'):
            mu_hx, w_mu_encoder, b_mu_encoder = dls.full_connect(_h2_encoder, [h2_size_encoder, embedding_size])
        with tf.variable_scope('feature_encoder_sigma'):
            sigma_hx, w_sigma_encoder, b_sigma_encoder = dls.full_connect(_h2_encoder, [h2_size_encoder, embedding_size])
        # mu_hx, sigma_hx = dls.vae_encoder(x, feature_size, h1_size_encoder, h2_size_encoder, embedding_size)
        # embedding_h[batch_size, T, embedding_size]
        embedding_h = tf.reshape(mu_hx, [batch_size, 1, embedding_size]) \
            + tf.reshape(sigma_hx, [batch_size, 1, -1]) \
            * tf.random_normal(shape=[batch_size, T, embedding_size], mean=0, stddev=1, dtype=tf.float32)

    with tf.variable_scope('q_hx_AE'):
        # x_reconstr, _, _ = dls.vae_decoder(mu_hx, embedding_size, h1_size_decoder, h2_size_decoder, feature_size)
        with tf.variable_scope('feature_decoder_h1'):
            _h1_decoder, w1_decoder, b1_decoder = dls.full_connect_relu_BN(mu_hx, [embedding_size, h1_size_decoder])
        with tf.variable_scope('feature_decoder_h2'):
            _h2_decoder, w2_decoder, b2_decoder = dls.full_connect_relu_BN(_h1_decoder, [h1_size_decoder, h2_size_decoder])
        # Bernoulli
        # with tf.variable_scope('feature_decoder_rho'):
        #     x_reconstr, w_rho_decoder, b_rho_decoder = dls.full_connect_sigmoid(_h2_decoder, [h2_size_decoder, feature_size])
        # Gaussian
        with tf.variable_scope('feature_decoder_rho'):
            x_reconstr, w_rho_decoder, b_rho_decoder = dls.full_connect(_h2_decoder, [h2_size_decoder, feature_size])
        
        # Bernoulli
        loss_cross_entropy_AE = -tf.reduce_mean(tf.reduce_sum(x*tf.log(1e-10+x_reconstr) + (1.0-x)*tf.log(1e-10+(1.0-x_reconstr)), -1))
        # Gaussian
        loss_square_AE = 0.5 * tf.reduce_mean(tf.square(x_reconstr - x))
        constraint_w_AE = 0.5 * (tf.reduce_mean(tf.square(w1_encoder)) + tf.reduce_mean(tf.square(b1_encoder))
            + tf.reduce_mean(tf.square(w2_encoder)) + tf.reduce_mean(tf.square(b2_encoder))
            + tf.reduce_mean(tf.square(w_mu_encoder)) + tf.reduce_mean(tf.square(b_mu_encoder))
            + tf.reduce_mean(tf.square(w1_decoder)) + tf.reduce_mean(tf.square(b1_decoder))
            + tf.reduce_mean(tf.square(w2_decoder)) + tf.reduce_mean(tf.square(b2_decoder))
            + tf.reduce_mean(tf.square(w_rho_decoder)) + tf.reduce_mean(tf.square(b_rho_decoder)))
        # Bernoulli
        # loss_AE = loss_cross_entropy_AE \
        #     + constraint_w_AE
        # Gaussian
        loss_AE = loss_square_AE \
            + constraint_w_AE
        learning_rate_AE = 0.02
        optimizer_AE = tf.train.AdamOptimizer(learning_rate=learning_rate_AE).minimize(loss_AE)

    #================= p(x|h) =====================
    with tf.variable_scope('q_hx_AE'):
        with tf.variable_scope('feature_decoder_h1', reuse=True):
            _h_VAE = tf.reshape(embedding_h, [-1, embedding_size])
            _h1_decoder_VAE, _, _ = dls.full_connect_relu_BN(_h_VAE, [embedding_size, h1_size_decoder])
        with tf.variable_scope('feature_decoder_h2', reuse=True):
            _h2_decoder_VAE, _, _ = dls.full_connect_relu_BN(_h1_decoder_VAE, [h1_size_decoder, h2_size_decoder])
        # Bernoulli
        # with tf.variable_scope('feature_decoder_rho', reuse=True):
        #     mu_xh, _, _ = dls.full_connect_sigmoid(_h2_decoder_VAE, [h2_size_decoder, feature_size])
        #     mu_xh = tf.reshape(mu_xh, [batch_size, T, feature_size])
        # Gaussian
        with tf.variable_scope('feature_decoder_rho', reuse=True):
            mu_xh, _, _ = dls.full_connect(_h2_decoder_VAE, [h2_size_decoder, feature_size])
            mu_xh = tf.reshape(mu_xh, [batch_size, T, feature_size])
            
    print('Encoders are constructed.')
    
#================= decoder p(l|y), p(x|h), p(y|z), p(h|z) and p(z) =====================
with tf.name_scope('decoder'):
    #================= p(l|y) =====================
    with tf.variable_scope('p_ly'):
        # pi_ly[category_size, 1, source_num*category_size]
        pi_ly, weights_ly, biases_ly = dls.LAA_decoder(source_num, category_size)

        constraint_w_LAA = 0.5 * (tf.reduce_mean(tf.square(weights_ly)) + tf.reduce_mean(tf.square(biases_ly))
            + tf.reduce_mean(tf.square(weights_yl)) + tf.reduce_mean(tf.square(biases_yl)))
        
    #================= p(y|z) =====================
    with tf.variable_scope('p_yz'):
        # pi_yz[cluster_num, category_size]
        _pi_yz = tf.get_variable('pi_yz', dtype=tf.float32, 
                                initializer=tf.random_normal(shape=[cluster_num, category_size], mean=0, stddev=1, dtype=tf.float32))
        __pi_yz = tf.exp(_pi_yz)
        pi_yz = tf.div(__pi_yz, tf.reduce_sum(__pi_yz, -1, keepdims=True))
        
        pi_yz_assign = tf.placeholder(dtype=tf.float32, shape=[cluster_num, category_size], name='pi_yz_assign')
        initialize_pi_yz = tf.assign(_pi_yz, pi_yz_assign)
        
    #================= p(h|z) =====================
    with tf.variable_scope('p_hz'):
        # mu_hz[cluster_num, embedding_size]
        # sigma_hz[cluster_num, embedding_size]
        mu_hz = tf.get_variable('mu_hz', dtype=tf.float32, initializer=tf.random_normal(shape=[cluster_num, embedding_size], mean=0, stddev=1, dtype=tf.float32))
        sigma_hz = tf.get_variable('sigma_hz', dtype=tf.float32, initializer=tf.ones([cluster_num, embedding_size], dtype=tf.float32))

        mu_hz_assign = tf.placeholder(dtype=tf.float32, shape=[cluster_num, embedding_size], name='mu_hz_assign')
        initialize_mu_hz = tf.assign(mu_hz, mu_hz_assign)
        
    #================= p(z) =====================
    with tf.variable_scope('p_z'):
        # pi_z_prior[batch_size, cluster_num]
        pi_z_prior = tf.placeholder(dtype=tf.float32, shape=[batch_size, cluster_num], name='pi_z_prior')
        _pi_z = tf.get_variable('pi_z', dtype=tf.float32, initializer=tf.ones([batch_size, cluster_num]))
        __pi_z = tf.exp(_pi_z)
        pi_z = tf.div(__pi_z, tf.reduce_sum(__pi_z, -1, keepdims=True))

        pi_z_assign = tf.placeholder(dtype=tf.float32, shape=[batch_size, cluster_num], name='pi_z_assign')
        initialize_pi_z = tf.assign(_pi_z, pi_z_assign)
    print('Decoders are constructed.')
    
#================= elbo =====================
'''
q(h|x) log p(x|h)
q(y|l) log p(l|y)
q(h|x) log q(h|x)
q(y|l) log q(y|l)
q(z|x,l)q(h|x) log p(h|z)
q(z|x,l)q(y|l) log p(y|z)
q(z|x,l) log p(z)
q(z|x,l) log q(z|x,l)
q(z|x,l)
'''
with tf.name_scope('elbo'):
    #================= q(h|x) log p(x|h) =====================
    with tf.name_scope('q_hx_log_p_xh'):
        # reduce_mean along both T and batch_size
        _tmp = tf.reshape(x, [batch_size, 1, feature_size])
        # Bernoulli
        # elbo_q_hx_log_p_xh = tf.reduce_mean(tf.reduce_sum(_tmp*tf.log(1e-10+mu_xh) + (1.0-_tmp)*tf.log(1e-10+(1.0-mu_xh)), -1))
        # Gaussian
        elbo_q_hx_log_p_xh = -0.5 * tf.reduce_mean(tf.reduce_sum(tf.square(_tmp-mu_xh), -1))
    
    #================= q(y|l) log p(l|y) =====================
    with tf.name_scope('q_yl_log_p_ly'):
        elbo_q_yl_log_p_ly = -dls.LAA_loss_reconstr(l, pi_ly, pi_yl)
        
    #================= q(h|x) log q(h|x) =====================
    with tf.name_scope('q_hx_log_q_hx'):
        elbo_q_hx_log_q_hx = -0.5 * tf.reduce_mean(tf.reduce_sum(tf.log(1e-10+tf.square(sigma_hx)), -1))

    #================= q(y|l) log q(y|l) =====================
    with tf.name_scope('q_yl_log_q_yl'):
        elbo_q_yl_log_q_yl = tf.reduce_mean(tf.reduce_sum(pi_yl * tf.log(1e-10+pi_yl), -1))
    
    #================= q(z|x,l) =====================
    with tf.name_scope('q_zxl'):
        # p(h|z)[batch_size, T, cluster_num, 1]
        _h = tf.reshape(embedding_h, [batch_size, T, 1, embedding_size])
        _p_hz = -0.5 * tf.reduce_sum(
            tf.div(tf.square(_h-mu_hz), 1e-10+tf.square(sigma_hz)) 
            + tf.log(1e-10 + tf.square(sigma_hz)), -1, keepdims=True)
        # p_zhy[batch_size, T, cluster_num, category_size]
        _p_zhy = tf.log(1e-10+pi_yz) + _p_hz + tf.log(1e-10+tf.reshape(pi_z, [batch_size, 1, cluster_num, 1]))
        _p_zhy_max = tf.reduce_max(_p_zhy, 2, keepdims=True)
        p_zhy = tf.exp(_p_zhy - (_p_zhy_max + tf.log(1e-10+tf.reduce_sum(tf.exp(_p_zhy-_p_zhy_max), 2, keepdims=True))))
        
        # q_zxl[batch_size, cluster_num]
        # reduce_mean along both category_size and T
        _q_zxl = tf.reduce_sum(tf.reshape(pi_yl, [batch_size, 1, 1, category_size]) * p_zhy, -1)
        q_zxl = tf.reduce_mean(_q_zxl, 1)
        
        # z_index[batch_size]
        z_index = tf.argmax(q_zxl, 1)
        # cluster_pi_max[batch_size, category_size]
        # cluster_pi_avg[batch_size, category_size]
        cluster_pi_max = tf.gather(pi_yz, z_index)
        cluster_pi_avg = tf.matmul(q_zxl, pi_yz)
        
    #================= q(z|x,l)q(h|x) log p(h|z) =====================
    #================= q(h|x) log p(h|z) [batch_size, cluster_num] =====================
    with tf.name_scope('q_zxl_q_hx_log_p_hz'):
        # mu_hx[batch_size, embedding_size]
        # sigma_hx[batch_size, embedding_size]
        # mu_hz[cluster_num, embedding_size]
        # sigma_hz[cluster_num, embedding_size]
        _part_1 = tf.div(tf.square(tf.reshape(mu_hx, [batch_size, 1, embedding_size]) - mu_hz), 1e-10+tf.square(sigma_hz))
        _part_2 = tf.div(tf.square(tf.reshape(sigma_hx, [batch_size, 1, -1])), 1e-10+tf.square(sigma_hz))
        _part_3 = tf.log(1e-10 + tf.square(sigma_hz))
        # elbo_q_hx_log_p_hz[batch_size, cluster_num]
        elbo_q_hx_log_p_hz = -0.5 * tf.reduce_sum(_part_1 + _part_2 + _part_3, -1)
        elbo_q_zxl_q_hx_log_p_hz = tf.reduce_mean(tf.reduce_sum(q_zxl * elbo_q_hx_log_p_hz, -1))
    
    #================= q(z|x,l)q(y|l) log p(y|z) =====================
    #================= q(y|l) log p(y|z) [batch_size, cluster_num] =====================
    with tf.name_scope('q_zxl_q_yl_log_p_yz'):
        # pi_yz[cluster_num, category_size]
        # pi_yl[batch_size, category_size]
        # elbo_q_yl_log_p_yz[batch_size, cluster_num]
        elbo_q_yl_log_p_yz = tf.reduce_sum(tf.reshape(pi_yl, [batch_size, 1, category_size]) * tf.log(1e-10 + pi_yz), -1)
        elbo_q_zxl_q_yl_log_p_yz = tf.reduce_mean(tf.reduce_sum(q_zxl * elbo_q_yl_log_p_yz, -1))
    
    #================= q(z|x,l) log p(z) =====================
    #================= log p(z) [cluster_num] =====================
    with tf.name_scope('q_zxl_log_p_z'):
        # elbo_log_p_z[batch_size, cluster_num]
        elbo_log_p_z = tf.log(1e-10 + pi_z)
        elbo_q_zxl_log_p_z = tf.reduce_mean(tf.reduce_sum(q_zxl * elbo_log_p_z, -1))
    
    #================= q(z|x,l) log q(z|x,l) =====================
    with tf.name_scope('q_zxl_log_q_zxl'):
        # q_zxl[batch_size, cluster_num]
        elbo_q_zxl_log_q_zxl = tf.reduce_mean(tf.reduce_sum(q_zxl * tf.log(1e-10 + q_zxl), -1))
    
    #================= overall elbo =====================
    elbo = elbo_q_hx_log_p_xh + elbo_q_yl_log_p_ly - elbo_q_hx_log_q_hx - elbo_q_yl_log_q_yl \
        + elbo_q_zxl_q_hx_log_p_hz + elbo_q_zxl_q_yl_log_p_yz + elbo_q_zxl_log_p_z - elbo_q_zxl_log_q_zxl    
    
    q_zxl_entropy = -elbo_q_zxl_log_q_zxl
    
    with tf.variable_scope('regularization_prior'):
        mu_hz_prior_mu = tf.placeholder(dtype=tf.float32, shape=[cluster_num, embedding_size], name='mu_hz_prior_mu')
        # sigma_hz_prior_alpha = tf.placeholder(dtype=tf.float32, shape=[cluster_num, embedding_size], name='sigma_hz_prior')
        pi_yz_prior = tf.placeholder(dtype=tf.float32, shape=[cluster_num, category_size], name='pi_yz_prior')
    
        constraint_prior = 0.5*tf.reduce_mean(tf.square(mu_hz - mu_hz_prior_mu)) \
            - tf.reduce_mean(pi_yz_prior * tf.log(1e-10+pi_yz)) \
            - tf.reduce_mean(pi_z_prior * tf.log(1e-10+pi_z)) \
            + tf.reduce_mean(1.0*tf.log(1e-10+tf.square(sigma_hz))+tf.div(2.0, 1e-10+tf.square(sigma_hz)))
    
    loss_overall = -elbo \
        + constraint_w_AE \
        + constraint_w_LAA \
        + 1.0 * constraint_prior
    
    # optimizier
    learning_rate_overall = 0.001
    optimizer_overall = tf.train.AdamOptimizer(learning_rate=learning_rate_overall).minimize(loss_overall)

    print('Clustering-based label-aware autoencoder is constructed.')

saver = tf.train.Saver()
# Out:
# file feature_rotten_tomatoes.npz loaded.
# Encoders are constructed.
# Decoders are constructed.
# Clustering-based label-aware autoencoder is constructed.

# %%
#================= training and inference =====================
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    #================= pre-train pi_yl =====================
    # assign batch variables (use whole data in one batch)
    # define majority voting regularizer
    majority_y = dls.get_majority_y(user_labels, source_num, category_size)
    # pre-train classifier
    print("Pre-train pi_yl ...")
    epochs = 50
    for epoch in range(epochs):
        _, monitor_pi_yl = sess.run([optimizer_pre_train_yl, pi_yl], 
            feed_dict={l:user_labels, pi_yl_target:majority_y})
        if epoch % 10 == 0:
            hit_num = dls.cal_hit_num(true_labels, monitor_pi_yl)
            print("epoch: {0} accuracy: {1}".format(epoch, float(hit_num)/n_samples))
    
    print("Pre-train hx_AE ...")
    epochs = 2000
    for epoch in range(epochs):
        _, monitor_loss_square_AE, monitor_mu_hx = sess.run([optimizer_AE, loss_square_AE, mu_hx], 
            feed_dict={x:feature})
        if epoch % 50 == 0:
            print("epoch: {0} loss: {1}".format(epoch, monitor_loss_square_AE))    
    
    #================= calculate initial parameters =====================
    clustering_result = KMeans(n_clusters=cluster_num).fit(monitor_mu_hx)
    # pi_z_prior_cluster = np.ones([n_samples, cluster_num]) / cluster_num
    pi_z_prior_cluster = dls.convert_to_one_hot(clustering_result.labels_, cluster_num, smooth=0.2)
    _ = sess.run(initialize_mu_hz, {mu_hz_assign:clustering_result.cluster_centers_})
    # pi_yz_prior_cluster = np.ones([cluster_num, category_size]) / cluster_num
    pi_yz_prior_cluster = dls.get_cluster_majority_y(
        clustering_result.labels_, user_labels, cluster_num, source_num, category_size)
    _ = sess.run(initialize_pi_yz, {pi_yz_assign:pi_yz_prior_cluster})
    _ = sess.run(initialize_pi_z, {pi_z_assign:pi_z_prior_cluster})
    
    mu_hz_prior_mu_cluster = clustering_result.cluster_centers_
    
    predict_label = np.zeros([batch_size, category_size])
    for i in range(batch_size):
        predict_label[i] = pi_yz_prior_cluster[clustering_result.labels_[i], :]
    print("Initial clustering accuracy: {0}".format(float(dls.cal_hit_num(true_labels, predict_label)) / n_samples))
    
    #================= save current model =====================
    saved_path = saver.save(sess, './my_model')
# Out:
# Pre-train pi_yl ...
# epoch: 0 accuracy: 0.4292858571714343
# epoch: 10 accuracy: 0.8817763552710542
# epoch: 20 accuracy: 0.8851770354070814
# epoch: 30 accuracy: 0.8839767953590718
# epoch: 40 accuracy: 0.8797759551910382
# Pre-train hx_AE ...
# epoch: 0 loss: 0.00338888936676085
# epoch: 50 loss: 0.0037123914808034897
# epoch: 100 loss: 0.003110635094344616
# epoch: 150 loss: 0.0031060657929629087
# epoch: 200 loss: 0.0031054250430315733
# epoch: 250 loss: 0.0031049256213009357
# epoch: 300 loss: 0.0031044953502714634
# epoch: 350 loss: 0.003103723982349038
# epoch: 400 loss: 0.003102862974628806
# epoch: 450 loss: 0.0031019081361591816
# epoch: 500 loss: 0.0031011253595352173
# epoch: 550 loss: 0.003100565169006586
# epoch: 600 loss: 0.003094357205554843
# epoch: 650 loss: 0.0030447538010776043
# epoch: 700 loss: 0.0030480907298624516
# epoch: 750 loss: 0.003037629649043083
# epoch: 800 loss: 0.0030515112448483706
# epoch: 850 loss: 0.0030331797897815704
# epoch: 900 loss: 0.003061167895793915
# epoch: 950 loss: 0.0029903845861554146
# epoch: 1000 loss: 0.002939581638202071
# epoch: 1050 loss: 0.0029404950328171253
# epoch: 1100 loss: 0.002931357128545642
# epoch: 1150 loss: 0.0030700189527124166
# epoch: 1200 loss: 0.0029992302879691124
# epoch: 1250 loss: 0.002967348089441657
# epoch: 1300 loss: 0.003051309147849679
# epoch: 1350 loss: 0.0029373951256275177
# epoch: 1400 loss: 0.0029173109214752913
# epoch: 1450 loss: 0.002900236053392291
# epoch: 1500 loss: 0.0028835139237344265
# epoch: 1550 loss: 0.002874941099435091
# epoch: 1600 loss: 0.002856847131624818
# epoch: 1650 loss: 0.0028365643229335546
# epoch: 1700 loss: 0.002816160675138235
# epoch: 1750 loss: 0.002796904416754842
# epoch: 1800 loss: 0.0027847415767610073
# epoch: 1850 loss: 0.0027720921207219362
# epoch: 1900 loss: 0.002748348517343402
# epoch: 1950 loss: 0.002724716905504465
# Initial clustering accuracy: 0.5507101420284057

# %%
with tf.Session() as sess:
    saver.restore(sess, './my_model')
    
    print("Train overall net ...")
    epochs = 2000
    for epoch in range(epochs):
        _, monitor_loss_overall, monitor_pi_yl, monitor_cluster_pi_max, monitor_cluster_pi_avg, \
            monitor_constraint_w_AE, monitor_constraint_prior = sess.run(
                [optimizer_overall, loss_overall, pi_yl, cluster_pi_max, cluster_pi_avg, constraint_w_AE, constraint_prior], 
                feed_dict={l:user_labels, x:feature, 
                           pi_z_prior:pi_z_prior_cluster, 
                           mu_hz_prior_mu:mu_hz_prior_mu_cluster, 
                           pi_yz_prior:pi_yz_prior_cluster})
        if epoch % 10 == 0:
            print("epoch: {0} loss: {1}".format(epoch, monitor_loss_overall))
            print("epoch: {0} loss: {1}".format(epoch, monitor_constraint_w_AE))
            print("epoch: {0} loss: {1}".format(epoch, monitor_constraint_prior))
            hit_num_object_level = dls.cal_hit_num(true_labels, monitor_pi_yl)
            hit_num_cluster_level_max = dls.cal_hit_num(true_labels, monitor_cluster_pi_max)
            hit_num_cluster_level_avg = dls.cal_hit_num(true_labels, monitor_cluster_pi_avg)
            print("epoch: {0} accuracy(object level): {1}".format(epoch, float(hit_num_object_level)/n_samples))
            print("epoch: {0} accuracy(cluster level max): {1}".format(epoch, float(hit_num_cluster_level_max)/n_samples))
            print("epoch: {0} accuracy(cluster level avg): {1}".format(epoch, float(hit_num_cluster_level_avg)/n_samples))
    print("Training overall net. Done!")
    
    monitor_q_zxl = sess.run(q_zxl, 
                feed_dict={l:user_labels, x:feature, 
                           pi_z_prior:pi_z_prior_cluster, 
                           mu_hz_prior_mu:mu_hz_prior_mu_cluster, 
                           pi_yz_prior:pi_yz_prior_cluster})
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model
# Train overall net ...
# epoch: 0 loss: 133.65753173828125
# epoch: 0 loss: 0.0002970878849737346
# epoch: 0 loss: 2.357433557510376
# epoch: 0 accuracy(object level): 0.8787757551510302
# epoch: 0 accuracy(cluster level max): 0.5507101420284057
# epoch: 0 accuracy(cluster level avg): 0.5581116223244649
# epoch: 10 loss: 67.91422271728516
# epoch: 10 loss: 0.00033901279675774276
# epoch: 10 loss: 2.3752553462982178
# epoch: 10 accuracy(object level): 0.8787757551510302
# epoch: 10 accuracy(cluster level max): 0.5509101820364073
# epoch: 10 accuracy(cluster level avg): 0.5309061812362472
# epoch: 20 loss: 51.75233459472656
# epoch: 20 loss: 0.00039256177842617035
# epoch: 20 loss: 2.3934593200683594
# epoch: 20 accuracy(object level): 0.878375675135027
# epoch: 20 accuracy(cluster level max): 0.5659131826365273
# epoch: 20 accuracy(cluster level avg): 0.5303060612122424
# epoch: 30 loss: 43.58746337890625
# epoch: 30 loss: 0.0004190959734842181
# epoch: 30 loss: 2.411226511001587
# epoch: 30 accuracy(object level): 0.877375475095019
# epoch: 30 accuracy(cluster level max): 0.5731146229245849
# epoch: 30 accuracy(cluster level avg): 0.5213042608521704
# epoch: 40 loss: 38.61795425415039
# epoch: 40 loss: 0.00043679040390998125
# epoch: 40 loss: 2.4278640747070312
# epoch: 40 accuracy(object level): 0.8771754350870175
# epoch: 40 accuracy(cluster level max): 0.5897179435887178
# epoch: 40 accuracy(cluster level avg): 0.5273054610922184
# epoch: 50 loss: 35.51310348510742
# epoch: 50 loss: 0.0004540008958429098
# epoch: 50 loss: 2.4428789615631104
# epoch: 50 accuracy(object level): 0.8775755151030206
# epoch: 50 accuracy(cluster level max): 0.5979195839167833
# epoch: 50 accuracy(cluster level avg): 0.5303060612122424
# epoch: 60 loss: 33.63196563720703
# epoch: 60 loss: 0.0004696697578765452
# epoch: 60 loss: 2.4557905197143555
# epoch: 60 accuracy(object level): 0.8777755551110222
# epoch: 60 accuracy(cluster level max): 0.5933186637327466
# epoch: 60 accuracy(cluster level avg): 0.5269053810762152
# epoch: 70 loss: 32.311397552490234
# epoch: 70 loss: 0.00048362347297370434
# epoch: 70 loss: 2.466599464416504
# epoch: 70 accuracy(object level): 0.8779755951190238
# epoch: 70 accuracy(cluster level max): 0.6013202640528106
# epoch: 70 accuracy(cluster level avg): 0.5327065413082617
# epoch: 80 loss: 31.20867919921875
# epoch: 80 loss: 0.0004980404046364129
# epoch: 80 loss: 2.4755008220672607
# epoch: 80 accuracy(object level): 0.8781756351270255
# epoch: 80 accuracy(cluster level max): 0.5883176635327065
# epoch: 80 accuracy(cluster level avg): 0.5265053010602121
# epoch: 90 loss: 30.380199432373047
# epoch: 90 loss: 0.0005115677486173809
# epoch: 90 loss: 2.482541084289551
# epoch: 90 accuracy(object level): 0.8785757151430286
# epoch: 90 accuracy(cluster level max): 0.592118423684737
# epoch: 90 accuracy(cluster level avg): 0.5333066613322665
# epoch: 100 loss: 29.781286239624023
# epoch: 100 loss: 0.0005276713636703789
# epoch: 100 loss: 2.487741470336914
# epoch: 100 accuracy(object level): 0.879375875175035
# epoch: 100 accuracy(cluster level max): 0.593118623724745
# epoch: 100 accuracy(cluster level avg): 0.5389077815563112
# epoch: 110 loss: 29.449665069580078
# epoch: 110 loss: 0.0005434361519291997
# epoch: 110 loss: 2.4912338256835938
# epoch: 110 accuracy(object level): 0.879375875175035
# epoch: 110 accuracy(cluster level max): 0.5885177035407081
# epoch: 110 accuracy(cluster level avg): 0.535507101420284
# epoch: 120 loss: 29.32006072998047
# epoch: 120 loss: 0.0005629510851576924
# epoch: 120 loss: 2.4936840534210205
# epoch: 120 accuracy(object level): 0.8801760352070415
# epoch: 120 accuracy(cluster level max): 0.5893178635727145
# epoch: 120 accuracy(cluster level avg): 0.5329065813162632
# epoch: 130 loss: 29.038284301757812
# epoch: 130 loss: 0.0005860632518306375
# epoch: 130 loss: 2.495722770690918
# epoch: 130 accuracy(object level): 0.8805761152230446
# epoch: 130 accuracy(cluster level max): 0.5807161432286457
# epoch: 130 accuracy(cluster level avg): 0.5321064212842569
# epoch: 140 loss: 28.79747772216797
# epoch: 140 loss: 0.0006084738997742534
# epoch: 140 loss: 2.4976108074188232
# epoch: 140 accuracy(object level): 0.8809761952390478
# epoch: 140 accuracy(cluster level max): 0.5785157031406282
# epoch: 140 accuracy(cluster level avg): 0.5317063412682537
# epoch: 150 loss: 28.458873748779297
# epoch: 150 loss: 0.0006332200719043612
# epoch: 150 loss: 2.4990386962890625
# epoch: 150 accuracy(object level): 0.8811762352470494
# epoch: 150 accuracy(cluster level max): 0.5805161032206442
# epoch: 150 accuracy(cluster level avg): 0.5337067413482697
# epoch: 160 loss: 28.3272647857666
# epoch: 160 loss: 0.000656604825053364
# epoch: 160 loss: 2.4994468688964844
# epoch: 160 accuracy(object level): 0.8825765153030606
# epoch: 160 accuracy(cluster level max): 0.5829165833166633
# epoch: 160 accuracy(cluster level avg): 0.5377075415083017
# epoch: 170 loss: 28.106855392456055
# epoch: 170 loss: 0.000672713911626488
# epoch: 170 loss: 2.4988255500793457
# epoch: 170 accuracy(object level): 0.8847769553910783
# epoch: 170 accuracy(cluster level max): 0.5741148229645929
# epoch: 170 accuracy(cluster level avg): 0.5293058611722344
# epoch: 180 loss: 27.95786476135254
# epoch: 180 loss: 0.000686478684656322
# epoch: 180 loss: 2.4976768493652344
# epoch: 180 accuracy(object level): 0.8871774354870974
# epoch: 180 accuracy(cluster level max): 0.5741148229645929
# epoch: 180 accuracy(cluster level avg): 0.5323064612922584
# epoch: 190 loss: 27.803253173828125
# epoch: 190 loss: 0.0006977958255447447
# epoch: 190 loss: 2.4959521293640137
# epoch: 190 accuracy(object level): 0.8907781556311263
# epoch: 190 accuracy(cluster level max): 0.5675135027005401
# epoch: 190 accuracy(cluster level avg): 0.5209041808361672
# epoch: 200 loss: 27.65365982055664
# epoch: 200 loss: 0.0007080009090714157
# epoch: 200 loss: 2.493866443634033
# epoch: 200 accuracy(object level): 0.8921784356871374
# epoch: 200 accuracy(cluster level max): 0.5803160632126425
# epoch: 200 accuracy(cluster level avg): 0.5291058211642329
# epoch: 210 loss: 27.46579360961914
# epoch: 210 loss: 0.0007121255621314049
# epoch: 210 loss: 2.491598606109619
# epoch: 210 accuracy(object level): 0.8933786757351471
# epoch: 210 accuracy(cluster level max): 0.5769153830766153
# epoch: 210 accuracy(cluster level avg): 0.5267053410682137
# epoch: 220 loss: 27.25383186340332
# epoch: 220 loss: 0.0007124029798433185
# epoch: 220 loss: 2.489070415496826
# epoch: 220 accuracy(object level): 0.8929785957191438
# epoch: 220 accuracy(cluster level max): 0.5805161032206442
# epoch: 220 accuracy(cluster level avg): 0.5245049009801961
# epoch: 230 loss: 27.08539581298828
# epoch: 230 loss: 0.0007123282412067056
# epoch: 230 loss: 2.486157178878784
# epoch: 230 accuracy(object level): 0.8943788757751551
# epoch: 230 accuracy(cluster level max): 0.5789157831566313
# epoch: 230 accuracy(cluster level avg): 0.5205041008201641
# epoch: 240 loss: 26.949356079101562
# epoch: 240 loss: 0.0007108035497367382
# epoch: 240 loss: 2.4828994274139404
# epoch: 240 accuracy(object level): 0.8943788757751551
# epoch: 240 accuracy(cluster level max): 0.5783156631326265
# epoch: 240 accuracy(cluster level avg): 0.5185037007401481
# epoch: 250 loss: 26.836273193359375
# epoch: 250 loss: 0.0007074534078128636
# epoch: 250 loss: 2.4795031547546387
# epoch: 250 accuracy(object level): 0.8947789557911582
# epoch: 250 accuracy(cluster level max): 0.5805161032206442
# epoch: 250 accuracy(cluster level avg): 0.5175035007001401
# epoch: 260 loss: 26.728227615356445
# epoch: 260 loss: 0.0007027405081316829
# epoch: 260 loss: 2.4760305881500244
# epoch: 260 accuracy(object level): 0.8949789957991598
# epoch: 260 accuracy(cluster level max): 0.5779155831166233
# epoch: 260 accuracy(cluster level avg): 0.5201040208041608
# epoch: 270 loss: 26.641897201538086
# epoch: 270 loss: 0.0006991350091993809
# epoch: 270 loss: 2.4724719524383545
# epoch: 270 accuracy(object level): 0.8957791558311662
# epoch: 270 accuracy(cluster level max): 0.5777155431086217
# epoch: 270 accuracy(cluster level avg): 0.5193038607721544
# epoch: 280 loss: 26.560253143310547
# epoch: 280 loss: 0.0006931807729415596
# epoch: 280 loss: 2.46875
# epoch: 280 accuracy(object level): 0.8965793158631726
# epoch: 280 accuracy(cluster level max): 0.583116623324665
# epoch: 280 accuracy(cluster level avg): 0.5195039007801561
# epoch: 290 loss: 26.4948787689209
# epoch: 290 loss: 0.0006855436367914081
# epoch: 290 loss: 2.464919328689575
# epoch: 290 accuracy(object level): 0.8969793958791759
# epoch: 290 accuracy(cluster level max): 0.5827165433086617
# epoch: 290 accuracy(cluster level avg): 0.5231046209241849
# epoch: 300 loss: 26.412158966064453
# epoch: 300 loss: 0.0006807573372498155
# epoch: 300 loss: 2.4610588550567627
# epoch: 300 accuracy(object level): 0.8977795559111822
# epoch: 300 accuracy(cluster level max): 0.5765153030606122
# epoch: 300 accuracy(cluster level avg): 0.5233046609321864
# epoch: 310 loss: 26.352312088012695
# epoch: 310 loss: 0.0006738730007782578
# epoch: 310 loss: 2.457212209701538
# epoch: 310 accuracy(object level): 0.8979795959191839
# epoch: 310 accuracy(cluster level max): 0.5877175435087018
# epoch: 310 accuracy(cluster level avg): 0.5291058211642329
# epoch: 320 loss: 26.29019546508789
# epoch: 320 loss: 0.0006675426848232746
# epoch: 320 loss: 2.4533026218414307
# epoch: 320 accuracy(object level): 0.8979795959191839
# epoch: 320 accuracy(cluster level max): 0.5769153830766153
# epoch: 320 accuracy(cluster level avg): 0.5319063812762552
# epoch: 330 loss: 26.21909523010254
# epoch: 330 loss: 0.0006606095121242106
# epoch: 330 loss: 2.4492886066436768
# epoch: 330 accuracy(object level): 0.8985797159431886
# epoch: 330 accuracy(cluster level max): 0.5817163432686537
# epoch: 330 accuracy(cluster level avg): 0.5383076615323065
# epoch: 340 loss: 26.170717239379883
# epoch: 340 loss: 0.0006547727389261127
# epoch: 340 loss: 2.445225954055786
# epoch: 340 accuracy(object level): 0.8989797959591919
# epoch: 340 accuracy(cluster level max): 0.5749149829965993
# epoch: 340 accuracy(cluster level avg): 0.5427085417083417
# epoch: 350 loss: 26.10636329650879
# epoch: 350 loss: 0.0006481314194388688
# epoch: 350 loss: 2.4411163330078125
# epoch: 350 accuracy(object level): 0.8997799559911982
# epoch: 350 accuracy(cluster level max): 0.5773154630926185
# epoch: 350 accuracy(cluster level avg): 0.5613122624524906
# epoch: 360 loss: 26.05899429321289
# epoch: 360 loss: 0.0006425841711461544
# epoch: 360 loss: 2.4369471073150635
# epoch: 360 accuracy(object level): 0.9003800760152031
# epoch: 360 accuracy(cluster level max): 0.5819163832766553
# epoch: 360 accuracy(cluster level avg): 0.5763152630526105
# epoch: 370 loss: 25.995893478393555
# epoch: 370 loss: 0.0006366759771481156
# epoch: 370 loss: 2.4327025413513184
# epoch: 370 accuracy(object level): 0.9001800360072014
# epoch: 370 accuracy(cluster level max): 0.5789157831566313
# epoch: 370 accuracy(cluster level avg): 0.5933186637327466
# epoch: 380 loss: 25.94618034362793
# epoch: 380 loss: 0.000630838330835104
# epoch: 380 loss: 2.4284377098083496
# epoch: 380 accuracy(object level): 0.9001800360072014
# epoch: 380 accuracy(cluster level max): 0.5763152630526105
# epoch: 380 accuracy(cluster level avg): 0.6303260652130426
# epoch: 390 loss: 25.89556884765625
# epoch: 390 loss: 0.0006241783266887069
# epoch: 390 loss: 2.4241232872009277
# epoch: 390 accuracy(object level): 0.8999799959991999
# epoch: 390 accuracy(cluster level max): 0.5759151830366073
# epoch: 390 accuracy(cluster level avg): 0.663132626525305
# epoch: 400 loss: 25.83625602722168
# epoch: 400 loss: 0.0006196629256010056
# epoch: 400 loss: 2.4197826385498047
# epoch: 400 accuracy(object level): 0.9001800360072014
# epoch: 400 accuracy(cluster level max): 0.5731146229245849
# epoch: 400 accuracy(cluster level avg): 0.6955391078215644
# epoch: 410 loss: 25.792827606201172
# epoch: 410 loss: 0.0006141057820059359
# epoch: 410 loss: 2.4154300689697266
# epoch: 410 accuracy(object level): 0.8999799959991999
# epoch: 410 accuracy(cluster level max): 0.5735147029405882
# epoch: 410 accuracy(cluster level avg): 0.7307461492298459
# epoch: 420 loss: 25.743581771850586
# epoch: 420 loss: 0.0006087282090447843
# epoch: 420 loss: 2.4110608100891113
# epoch: 420 accuracy(object level): 0.8999799959991999
# epoch: 420 accuracy(cluster level max): 0.5739147829565913
# epoch: 420 accuracy(cluster level avg): 0.7605521104220844
# epoch: 430 loss: 25.696529388427734
# epoch: 430 loss: 0.0006039037252776325
# epoch: 430 loss: 2.4066829681396484
# epoch: 430 accuracy(object level): 0.8999799959991999
# epoch: 430 accuracy(cluster level max): 0.5783156631326265
# epoch: 430 accuracy(cluster level avg): 0.7851570314062812
# epoch: 440 loss: 25.641796112060547
# epoch: 440 loss: 0.0005979124689474702
# epoch: 440 loss: 2.4022648334503174
# epoch: 440 accuracy(object level): 0.8997799559911982
# epoch: 440 accuracy(cluster level max): 0.5713142628525705
# epoch: 440 accuracy(cluster level avg): 0.8053610722144429
# epoch: 450 loss: 25.60068702697754
# epoch: 450 loss: 0.0005930841434746981
# epoch: 450 loss: 2.3978641033172607
# epoch: 450 accuracy(object level): 0.8993798759751951
# epoch: 450 accuracy(cluster level max): 0.5763152630526105
# epoch: 450 accuracy(cluster level avg): 0.8201640328065614
# epoch: 460 loss: 25.558910369873047
# epoch: 460 loss: 0.0005888795712962747
# epoch: 460 loss: 2.393467903137207
# epoch: 460 accuracy(object level): 0.8997799559911982
# epoch: 460 accuracy(cluster level max): 0.5777155431086217
# epoch: 460 accuracy(cluster level avg): 0.8271654330866173
# epoch: 470 loss: 25.521608352661133
# epoch: 470 loss: 0.0005857280921190977
# epoch: 470 loss: 2.3891146183013916
# epoch: 470 accuracy(object level): 0.9001800360072014
# epoch: 470 accuracy(cluster level max): 0.5753150630126025
# epoch: 470 accuracy(cluster level avg): 0.8399679935987198
# epoch: 480 loss: 25.477466583251953
# epoch: 480 loss: 0.0005819263169541955
# epoch: 480 loss: 2.3847577571868896
# epoch: 480 accuracy(object level): 0.9003800760152031
# epoch: 480 accuracy(cluster level max): 0.5747149429885977
# epoch: 480 accuracy(cluster level avg): 0.8495699139827966
# epoch: 490 loss: 25.43149185180664
# epoch: 490 loss: 0.000578789331484586
# epoch: 490 loss: 2.3804197311401367
# epoch: 490 accuracy(object level): 0.9007801560312062
# epoch: 490 accuracy(cluster level max): 0.5773154630926185
# epoch: 490 accuracy(cluster level avg): 0.8569713942788558
# epoch: 500 loss: 25.390045166015625
# epoch: 500 loss: 0.0005752997240051627
# epoch: 500 loss: 2.376060962677002
# epoch: 500 accuracy(object level): 0.9005801160232046
# epoch: 500 accuracy(cluster level max): 0.5783156631326265
# epoch: 500 accuracy(cluster level avg): 0.8655731146229246
# epoch: 510 loss: 25.3413028717041
# epoch: 510 loss: 0.0005721662892028689
# epoch: 510 loss: 2.3717010021209717
# epoch: 510 accuracy(object level): 0.9005801160232046
# epoch: 510 accuracy(cluster level max): 0.5767153430686137
# epoch: 510 accuracy(cluster level avg): 0.868373674734947
# epoch: 520 loss: 25.311304092407227
# epoch: 520 loss: 0.0005678802262991667
# epoch: 520 loss: 2.36741304397583
# epoch: 520 accuracy(object level): 0.9003800760152031
# epoch: 520 accuracy(cluster level max): 0.5805161032206442
# epoch: 520 accuracy(cluster level avg): 0.871374274854971
# epoch: 530 loss: 25.266761779785156
# epoch: 530 loss: 0.0005642116302624345
# epoch: 530 loss: 2.363142490386963
# epoch: 530 accuracy(object level): 0.9003800760152031
# epoch: 530 accuracy(cluster level max): 0.5789157831566313
# epoch: 530 accuracy(cluster level avg): 0.8751750350070014
# epoch: 540 loss: 25.232059478759766
# epoch: 540 loss: 0.0005616635899059474
# epoch: 540 loss: 2.3588685989379883
# epoch: 540 accuracy(object level): 0.9003800760152031
# epoch: 540 accuracy(cluster level max): 0.5813162632526505
# epoch: 540 accuracy(cluster level avg): 0.8799759951990398
# epoch: 550 loss: 25.194747924804688
# epoch: 550 loss: 0.0005592521629296243
# epoch: 550 loss: 2.3546319007873535
# epoch: 550 accuracy(object level): 0.9003800760152031
# epoch: 550 accuracy(cluster level max): 0.5885177035407081
# epoch: 550 accuracy(cluster level avg): 0.8841768353670734
# epoch: 560 loss: 25.161376953125
# epoch: 560 loss: 0.0005561255384236574
# epoch: 560 loss: 2.3504912853240967
# epoch: 560 accuracy(object level): 0.9009801960392079
# epoch: 560 accuracy(cluster level max): 0.593118623724745
# epoch: 560 accuracy(cluster level avg): 0.8869773954790958
# epoch: 570 loss: 25.12804412841797
# epoch: 570 loss: 0.0005536915850825608
# epoch: 570 loss: 2.34639310836792
# epoch: 570 accuracy(object level): 0.9009801960392079
# epoch: 570 accuracy(cluster level max): 0.6001200240048009
# epoch: 570 accuracy(cluster level avg): 0.8841768353670734
# epoch: 580 loss: 25.092317581176758
# epoch: 580 loss: 0.0005519830156117678
# epoch: 580 loss: 2.342278003692627
# epoch: 580 accuracy(object level): 0.9009801960392079
# epoch: 580 accuracy(cluster level max): 0.6055211042208442
# epoch: 580 accuracy(cluster level avg): 0.8881776355271054
# epoch: 590 loss: 25.053049087524414
# epoch: 590 loss: 0.0005491100018844008
# epoch: 590 loss: 2.3382506370544434
# epoch: 590 accuracy(object level): 0.9009801960392079
# epoch: 590 accuracy(cluster level max): 0.6165233046609322
# epoch: 590 accuracy(cluster level avg): 0.8915783156631326
# epoch: 600 loss: 25.03272819519043
# epoch: 600 loss: 0.0005471851327456534
# epoch: 600 loss: 2.3342976570129395
# epoch: 600 accuracy(object level): 0.9009801960392079
# epoch: 600 accuracy(cluster level max): 0.618123624724945
# epoch: 600 accuracy(cluster level avg): 0.8911782356471294
# epoch: 610 loss: 24.98805809020996
# epoch: 610 loss: 0.0005450992030091584
# epoch: 610 loss: 2.330404281616211
# epoch: 610 accuracy(object level): 0.9009801960392079
# epoch: 610 accuracy(cluster level max): 0.6253250650130026
# epoch: 610 accuracy(cluster level avg): 0.8923784756951391
# epoch: 620 loss: 24.964006423950195
# epoch: 620 loss: 0.0005429196171462536
# epoch: 620 loss: 2.326594829559326
# epoch: 620 accuracy(object level): 0.9013802760552111
# epoch: 620 accuracy(cluster level max): 0.6347269453890778
# epoch: 620 accuracy(cluster level avg): 0.8929785957191438
# epoch: 630 loss: 24.92759895324707
# epoch: 630 loss: 0.0005409797304309905
# epoch: 630 loss: 2.322817087173462
# epoch: 630 accuracy(object level): 0.9015803160632127
# epoch: 630 accuracy(cluster level max): 0.6427285457091418
# epoch: 630 accuracy(cluster level avg): 0.8919783956791358
# epoch: 640 loss: 24.89956283569336
# epoch: 640 loss: 0.0005395991611294448
# epoch: 640 loss: 2.3190927505493164
# epoch: 640 accuracy(object level): 0.9015803160632127
# epoch: 640 accuracy(cluster level max): 0.6553310662132427
# epoch: 640 accuracy(cluster level avg): 0.8935787157431486
# epoch: 650 loss: 24.863788604736328
# epoch: 650 loss: 0.0005382512463256717
# epoch: 650 loss: 2.3154349327087402
# epoch: 650 accuracy(object level): 0.9015803160632127
# epoch: 650 accuracy(cluster level max): 0.6585317063412682
# epoch: 650 accuracy(cluster level avg): 0.8959791958391679
# epoch: 660 loss: 24.845258712768555
# epoch: 660 loss: 0.0005369241698645055
# epoch: 660 loss: 2.311868667602539
# epoch: 660 accuracy(object level): 0.9017803560712142
# epoch: 660 accuracy(cluster level max): 0.6775355071014203
# epoch: 660 accuracy(cluster level avg): 0.8971794358871774
# epoch: 670 loss: 24.804588317871094
# epoch: 670 loss: 0.0005356637411750853
# epoch: 670 loss: 2.308377981185913
# epoch: 670 accuracy(object level): 0.9015803160632127
# epoch: 670 accuracy(cluster level max): 0.6845369073814763
# epoch: 670 accuracy(cluster level avg): 0.8977795559111822
# epoch: 680 loss: 24.782129287719727
# epoch: 680 loss: 0.0005347061087377369
# epoch: 680 loss: 2.3049893379211426
# epoch: 680 accuracy(object level): 0.9015803160632127
# epoch: 680 accuracy(cluster level max): 0.6939387877575515
# epoch: 680 accuracy(cluster level avg): 0.8965793158631726
# epoch: 690 loss: 24.754653930664062
# epoch: 690 loss: 0.0005334684974513948
# epoch: 690 loss: 2.301668167114258
# epoch: 690 accuracy(object level): 0.9015803160632127
# epoch: 690 accuracy(cluster level max): 0.7071414282856572
# epoch: 690 accuracy(cluster level avg): 0.8975795159031806
# epoch: 700 loss: 24.724594116210938
# epoch: 700 loss: 0.000532931589987129
# epoch: 700 loss: 2.2984015941619873
# epoch: 700 accuracy(object level): 0.9017803560712142
# epoch: 700 accuracy(cluster level max): 0.7281456291258251
# epoch: 700 accuracy(cluster level avg): 0.8985797159431886
# epoch: 710 loss: 24.698352813720703
# epoch: 710 loss: 0.0005319411866366863
# epoch: 710 loss: 2.2952141761779785
# epoch: 710 accuracy(object level): 0.9021804360872174
# epoch: 710 accuracy(cluster level max): 0.7413482696539307
# epoch: 710 accuracy(cluster level avg): 0.8979795959191839
# epoch: 720 loss: 24.683399200439453
# epoch: 720 loss: 0.0005308768013492227
# epoch: 720 loss: 2.292076826095581
# epoch: 720 accuracy(object level): 0.9021804360872174
# epoch: 720 accuracy(cluster level max): 0.756751350270054
# epoch: 720 accuracy(cluster level avg): 0.8987797559511902
# epoch: 730 loss: 24.656463623046875
# epoch: 730 loss: 0.000529513054061681
# epoch: 730 loss: 2.289012908935547
# epoch: 730 accuracy(object level): 0.9025805161032207
# epoch: 730 accuracy(cluster level max): 0.7681536307261452
# epoch: 730 accuracy(cluster level avg): 0.8977795559111822
# epoch: 740 loss: 24.635967254638672
# epoch: 740 loss: 0.0005290025728754699
# epoch: 740 loss: 2.286015510559082
# epoch: 740 accuracy(object level): 0.9023804760952191
# epoch: 740 accuracy(cluster level max): 0.7761552310462092
# epoch: 740 accuracy(cluster level avg): 0.8983796759351871
# epoch: 750 loss: 24.60422134399414
# epoch: 750 loss: 0.0005282837082631886
# epoch: 750 loss: 2.283109426498413
# epoch: 750 accuracy(object level): 0.9025805161032207
# epoch: 750 accuracy(cluster level max): 0.7861572314462892
# epoch: 750 accuracy(cluster level avg): 0.8995799159831966
# epoch: 760 loss: 24.579721450805664
# epoch: 760 loss: 0.0005281720077618957
# epoch: 760 loss: 2.280269145965576
# epoch: 760 accuracy(object level): 0.9025805161032207
# epoch: 760 accuracy(cluster level max): 0.8017603520704141
# epoch: 760 accuracy(cluster level avg): 0.9003800760152031
# epoch: 770 loss: 24.563251495361328
# epoch: 770 loss: 0.000527277821674943
# epoch: 770 loss: 2.2774658203125
# epoch: 770 accuracy(object level): 0.9025805161032207
# epoch: 770 accuracy(cluster level max): 0.8067613522704541
# epoch: 770 accuracy(cluster level avg): 0.8987797559511902
# epoch: 780 loss: 24.537372589111328
# epoch: 780 loss: 0.000526434916537255
# epoch: 780 loss: 2.274728298187256
# epoch: 780 accuracy(object level): 0.9027805561112222
# epoch: 780 accuracy(cluster level max): 0.8167633526705341
# epoch: 780 accuracy(cluster level avg): 0.8999799959991999
# epoch: 790 loss: 24.513216018676758
# epoch: 790 loss: 0.0005264607607387006
# epoch: 790 loss: 2.272094249725342
# epoch: 790 accuracy(object level): 0.9027805561112222
# epoch: 790 accuracy(cluster level max): 0.8249649929985997
# epoch: 790 accuracy(cluster level avg): 0.8997799559911982
# epoch: 800 loss: 24.49960708618164
# epoch: 800 loss: 0.0005257476586848497
# epoch: 800 loss: 2.2695295810699463
# epoch: 800 accuracy(object level): 0.9027805561112222
# epoch: 800 accuracy(cluster level max): 0.8335667133426685
# epoch: 800 accuracy(cluster level avg): 0.9007801560312062
# epoch: 810 loss: 24.473880767822266
# epoch: 810 loss: 0.0005249190726317465
# epoch: 810 loss: 2.2669765949249268
# epoch: 810 accuracy(object level): 0.9029805961192239
# epoch: 810 accuracy(cluster level max): 0.8427685537107421
# epoch: 810 accuracy(cluster level avg): 0.9007801560312062
# epoch: 820 loss: 24.45546531677246
# epoch: 820 loss: 0.0005247063236311078
# epoch: 820 loss: 2.264482021331787
# epoch: 820 accuracy(object level): 0.9033806761352271
# epoch: 820 accuracy(cluster level max): 0.8471694338867773
# epoch: 820 accuracy(cluster level avg): 0.9017803560712142
# epoch: 830 loss: 24.428707122802734
# epoch: 830 loss: 0.0005238794256001711
# epoch: 830 loss: 2.262065887451172
# epoch: 830 accuracy(object level): 0.9033806761352271
# epoch: 830 accuracy(cluster level max): 0.8537707541508301
# epoch: 830 accuracy(cluster level avg): 0.9013802760552111
# epoch: 840 loss: 24.417625427246094
# epoch: 840 loss: 0.0005233479896560311
# epoch: 840 loss: 2.2597174644470215
# epoch: 840 accuracy(object level): 0.9037807561512302
# epoch: 840 accuracy(cluster level max): 0.8571714342868574
# epoch: 840 accuracy(cluster level avg): 0.9013802760552111
# epoch: 850 loss: 24.398170471191406
# epoch: 850 loss: 0.0005229450762271881
# epoch: 850 loss: 2.2574079036712646
# epoch: 850 accuracy(object level): 0.9037807561512302
# epoch: 850 accuracy(cluster level max): 0.8601720344068814
# epoch: 850 accuracy(cluster level avg): 0.9017803560712142
# epoch: 860 loss: 24.384075164794922
# epoch: 860 loss: 0.0005228214431554079
# epoch: 860 loss: 2.255112648010254
# epoch: 860 accuracy(object level): 0.9039807961592319
# epoch: 860 accuracy(cluster level max): 0.8617723544708942
# epoch: 860 accuracy(cluster level avg): 0.9019803960792159
# epoch: 870 loss: 24.358135223388672
# epoch: 870 loss: 0.0005220477469265461
# epoch: 870 loss: 2.2528553009033203
# epoch: 870 accuracy(object level): 0.9041808361672334
# epoch: 870 accuracy(cluster level max): 0.8657731546309262
# epoch: 870 accuracy(cluster level avg): 0.9025805161032207
# epoch: 880 loss: 24.34319305419922
# epoch: 880 loss: 0.0005220266757532954
# epoch: 880 loss: 2.2506263256073
# epoch: 880 accuracy(object level): 0.9041808361672334
# epoch: 880 accuracy(cluster level max): 0.8677735547109422
# epoch: 880 accuracy(cluster level avg): 0.9021804360872174
# epoch: 890 loss: 24.325782775878906
# epoch: 890 loss: 0.0005216454737819731
# epoch: 890 loss: 2.248459577560425
# epoch: 890 accuracy(object level): 0.904380876175235
# epoch: 890 accuracy(cluster level max): 0.8719743948789758
# epoch: 890 accuracy(cluster level avg): 0.9019803960792159
# epoch: 900 loss: 24.307233810424805
# epoch: 900 loss: 0.0005208920920267701
# epoch: 900 loss: 2.2463207244873047
# epoch: 900 accuracy(object level): 0.9047809561912382
# epoch: 900 accuracy(cluster level max): 0.8715743148629725
# epoch: 900 accuracy(cluster level avg): 0.9027805561112222
# epoch: 910 loss: 24.292606353759766
# epoch: 910 loss: 0.0005214429693296552
# epoch: 910 loss: 2.2442116737365723
# epoch: 910 accuracy(object level): 0.9047809561912382
# epoch: 910 accuracy(cluster level max): 0.8745749149829966
# epoch: 910 accuracy(cluster level avg): 0.9031806361272254
# epoch: 920 loss: 24.27387237548828
# epoch: 920 loss: 0.0005211816751398146
# epoch: 920 loss: 2.242137908935547
# epoch: 920 accuracy(object level): 0.9045809161832367
# epoch: 920 accuracy(cluster level max): 0.8737747549509902
# epoch: 920 accuracy(cluster level avg): 0.9029805961192239
# epoch: 930 loss: 24.258296966552734
# epoch: 930 loss: 0.0005209425580687821
# epoch: 930 loss: 2.2401134967803955
# epoch: 930 accuracy(object level): 0.9045809161832367
# epoch: 930 accuracy(cluster level max): 0.876375275055011
# epoch: 930 accuracy(cluster level avg): 0.9033806761352271
# epoch: 940 loss: 24.253061294555664
# epoch: 940 loss: 0.000520103785675019
# epoch: 940 loss: 2.2381057739257812
# epoch: 940 accuracy(object level): 0.9045809161832367
# epoch: 940 accuracy(cluster level max): 0.8767753550710142
# epoch: 940 accuracy(cluster level avg): 0.9031806361272254
# epoch: 950 loss: 24.227113723754883
# epoch: 950 loss: 0.000520306930411607
# epoch: 950 loss: 2.236118793487549
# epoch: 950 accuracy(object level): 0.9049809961992399
# epoch: 950 accuracy(cluster level max): 0.8807761552310462
# epoch: 950 accuracy(cluster level avg): 0.9029805961192239
# epoch: 960 loss: 24.2216854095459
# epoch: 960 loss: 0.0005203225882723927
# epoch: 960 loss: 2.2341840267181396
# epoch: 960 accuracy(object level): 0.905381076215243
# epoch: 960 accuracy(cluster level max): 0.8801760352070415
# epoch: 960 accuracy(cluster level avg): 0.9033806761352271
# epoch: 970 loss: 24.20209312438965
# epoch: 970 loss: 0.0005196299171075225
# epoch: 970 loss: 2.2322561740875244
# epoch: 970 accuracy(object level): 0.9051810362072414
# epoch: 970 accuracy(cluster level max): 0.8817763552710542
# epoch: 970 accuracy(cluster level avg): 0.9031806361272254
# epoch: 980 loss: 24.188060760498047
# epoch: 980 loss: 0.0005196768906898797
# epoch: 980 loss: 2.230367660522461
# epoch: 980 accuracy(object level): 0.9051810362072414
# epoch: 980 accuracy(cluster level max): 0.883376675335067
# epoch: 980 accuracy(cluster level avg): 0.9039807961592319
# epoch: 990 loss: 24.172731399536133
# epoch: 990 loss: 0.0005194434197619557
# epoch: 990 loss: 2.2285001277923584
# epoch: 990 accuracy(object level): 0.9051810362072414
# epoch: 990 accuracy(cluster level max): 0.8839767953590718
# epoch: 990 accuracy(cluster level avg): 0.9037807561512302
# epoch: 1000 loss: 24.159523010253906
# epoch: 1000 loss: 0.0005190705414861441
# epoch: 1000 loss: 2.226649522781372
# epoch: 1000 accuracy(object level): 0.9051810362072414
# epoch: 1000 accuracy(cluster level max): 0.883376675335067
# epoch: 1000 accuracy(cluster level avg): 0.9039807961592319
# epoch: 1010 loss: 24.14628028869629
# epoch: 1010 loss: 0.0005188070936128497
# epoch: 1010 loss: 2.224829912185669
# epoch: 1010 accuracy(object level): 0.9051810362072414
# epoch: 1010 accuracy(cluster level max): 0.8849769953990798
# epoch: 1010 accuracy(cluster level avg): 0.9031806361272254
# epoch: 1020 loss: 24.13485336303711
# epoch: 1020 loss: 0.0005185312475077808
# epoch: 1020 loss: 2.2230396270751953
# epoch: 1020 accuracy(object level): 0.905381076215243
# epoch: 1020 accuracy(cluster level max): 0.8867773554710943
# epoch: 1020 accuracy(cluster level avg): 0.9035807161432287
# epoch: 1030 loss: 24.120513916015625
# epoch: 1030 loss: 0.000518463202752173
# epoch: 1030 loss: 2.2212836742401123
# epoch: 1030 accuracy(object level): 0.9055811162232447
# epoch: 1030 accuracy(cluster level max): 0.8865773154630926
# epoch: 1030 accuracy(cluster level avg): 0.9037807561512302
# epoch: 1040 loss: 24.10752296447754
# epoch: 1040 loss: 0.0005181972519494593
# epoch: 1040 loss: 2.219566822052002
# epoch: 1040 accuracy(object level): 0.9055811162232447
# epoch: 1040 accuracy(cluster level max): 0.8875775155031006
# epoch: 1040 accuracy(cluster level avg): 0.9037807561512302
# epoch: 1050 loss: 24.09980010986328
# epoch: 1050 loss: 0.0005181679734960198
# epoch: 1050 loss: 2.217869758605957
# epoch: 1050 accuracy(object level): 0.9057811562312462
# epoch: 1050 accuracy(cluster level max): 0.888377675535107
# epoch: 1050 accuracy(cluster level avg): 0.9033806761352271
# epoch: 1060 loss: 24.083066940307617
# epoch: 1060 loss: 0.0005178085993975401
# epoch: 1060 loss: 2.2161734104156494
# epoch: 1060 accuracy(object level): 0.9057811562312462
# epoch: 1060 accuracy(cluster level max): 0.8875775155031006
# epoch: 1060 accuracy(cluster level avg): 0.9041808361672334
# epoch: 1070 loss: 24.084314346313477
# epoch: 1070 loss: 0.0005177020211704075
# epoch: 1070 loss: 2.2144927978515625
# epoch: 1070 accuracy(object level): 0.9061812362472494
# epoch: 1070 accuracy(cluster level max): 0.890378075615123
# epoch: 1070 accuracy(cluster level avg): 0.9039807961592319
# epoch: 1080 loss: 24.061262130737305
# epoch: 1080 loss: 0.0005174751277081668
# epoch: 1080 loss: 2.2128522396087646
# epoch: 1080 accuracy(object level): 0.9061812362472494
# epoch: 1080 accuracy(cluster level max): 0.8895779155831166
# epoch: 1080 accuracy(cluster level avg): 0.9047809561912382
# epoch: 1090 loss: 24.052715301513672
# epoch: 1090 loss: 0.0005174179095774889
# epoch: 1090 loss: 2.2112550735473633
# epoch: 1090 accuracy(object level): 0.906381276255251
# epoch: 1090 accuracy(cluster level max): 0.8901780356071214
# epoch: 1090 accuracy(cluster level avg): 0.904380876175235
# epoch: 1100 loss: 24.042936325073242
# epoch: 1100 loss: 0.000517002830747515
# epoch: 1100 loss: 2.2096810340881348
# epoch: 1100 accuracy(object level): 0.906381276255251
# epoch: 1100 accuracy(cluster level max): 0.8895779155831166
# epoch: 1100 accuracy(cluster level avg): 0.9047809561912382
# epoch: 1110 loss: 24.031047821044922
# epoch: 1110 loss: 0.0005165622569620609
# epoch: 1110 loss: 2.2081310749053955
# epoch: 1110 accuracy(object level): 0.9065813162632527
# epoch: 1110 accuracy(cluster level max): 0.8917783556711343
# epoch: 1110 accuracy(cluster level avg): 0.905381076215243
# epoch: 1120 loss: 24.022157669067383
# epoch: 1120 loss: 0.0005162247689440846
# epoch: 1120 loss: 2.2066051959991455
# epoch: 1120 accuracy(object level): 0.9067813562712542
# epoch: 1120 accuracy(cluster level max): 0.8915783156631326
# epoch: 1120 accuracy(cluster level avg): 0.9051810362072414
# epoch: 1130 loss: 24.009654998779297
# epoch: 1130 loss: 0.000515800784341991
# epoch: 1130 loss: 2.205080270767212
# epoch: 1130 accuracy(object level): 0.906381276255251
# epoch: 1130 accuracy(cluster level max): 0.8913782756551311
# epoch: 1130 accuracy(cluster level avg): 0.9049809961992399
# epoch: 1140 loss: 23.999874114990234
# epoch: 1140 loss: 0.0005152747617103159
# epoch: 1140 loss: 2.2035717964172363
# epoch: 1140 accuracy(object level): 0.906381276255251
# epoch: 1140 accuracy(cluster level max): 0.8923784756951391
# epoch: 1140 accuracy(cluster level avg): 0.9049809961992399
# epoch: 1150 loss: 23.988224029541016
# epoch: 1150 loss: 0.0005154876271262765
# epoch: 1150 loss: 2.202094078063965
# epoch: 1150 accuracy(object level): 0.9067813562712542
# epoch: 1150 accuracy(cluster level max): 0.8925785157031406
# epoch: 1150 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1160 loss: 23.979881286621094
# epoch: 1160 loss: 0.0005147565389052033
# epoch: 1160 loss: 2.200662136077881
# epoch: 1160 accuracy(object level): 0.9067813562712542
# epoch: 1160 accuracy(cluster level max): 0.8931786357271454
# epoch: 1160 accuracy(cluster level avg): 0.9055811162232447
# epoch: 1170 loss: 23.97295379638672
# epoch: 1170 loss: 0.0005143840098753572
# epoch: 1170 loss: 2.1992385387420654
# epoch: 1170 accuracy(object level): 0.9069813962792559
# epoch: 1170 accuracy(cluster level max): 0.8949789957991598
# epoch: 1170 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1180 loss: 23.962032318115234
# epoch: 1180 loss: 0.0005141068249940872
# epoch: 1180 loss: 2.1978237628936768
# epoch: 1180 accuracy(object level): 0.9069813962792559
# epoch: 1180 accuracy(cluster level max): 0.8941788357671534
# epoch: 1180 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1190 loss: 23.956941604614258
# epoch: 1190 loss: 0.0005139791173860431
# epoch: 1190 loss: 2.196429491043091
# epoch: 1190 accuracy(object level): 0.9067813562712542
# epoch: 1190 accuracy(cluster level max): 0.8963792758551711
# epoch: 1190 accuracy(cluster level avg): 0.9051810362072414
# epoch: 1200 loss: 23.944019317626953
# epoch: 1200 loss: 0.0005133950035087764
# epoch: 1200 loss: 2.195066452026367
# epoch: 1200 accuracy(object level): 0.9069813962792559
# epoch: 1200 accuracy(cluster level max): 0.8955791158231646
# epoch: 1200 accuracy(cluster level avg): 0.9055811162232447
# epoch: 1210 loss: 23.940610885620117
# epoch: 1210 loss: 0.0005125606548972428
# epoch: 1210 loss: 2.1937127113342285
# epoch: 1210 accuracy(object level): 0.9069813962792559
# epoch: 1210 accuracy(cluster level max): 0.8965793158631726
# epoch: 1210 accuracy(cluster level avg): 0.9057811562312462
# epoch: 1220 loss: 23.925884246826172
# epoch: 1220 loss: 0.0005122387083247304
# epoch: 1220 loss: 2.192375659942627
# epoch: 1220 accuracy(object level): 0.9069813962792559
# epoch: 1220 accuracy(cluster level max): 0.8959791958391679
# epoch: 1220 accuracy(cluster level avg): 0.9057811562312462
# epoch: 1230 loss: 23.91663932800293
# epoch: 1230 loss: 0.0005114911473356187
# epoch: 1230 loss: 2.1910722255706787
# epoch: 1230 accuracy(object level): 0.9071814362872574
# epoch: 1230 accuracy(cluster level max): 0.8963792758551711
# epoch: 1230 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1240 loss: 23.912363052368164
# epoch: 1240 loss: 0.0005110993515700102
# epoch: 1240 loss: 2.1897923946380615
# epoch: 1240 accuracy(object level): 0.907381476295259
# epoch: 1240 accuracy(cluster level max): 0.8975795159031806
# epoch: 1240 accuracy(cluster level avg): 0.9057811562312462
# epoch: 1250 loss: 23.902076721191406
# epoch: 1250 loss: 0.0005110102938488126
# epoch: 1250 loss: 2.1885318756103516
# epoch: 1250 accuracy(object level): 0.9071814362872574
# epoch: 1250 accuracy(cluster level max): 0.8983796759351871
# epoch: 1250 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1260 loss: 23.893123626708984
# epoch: 1260 loss: 0.0005106587777845562
# epoch: 1260 loss: 2.1872849464416504
# epoch: 1260 accuracy(object level): 0.9071814362872574
# epoch: 1260 accuracy(cluster level max): 0.8993798759751951
# epoch: 1260 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1270 loss: 23.88986587524414
# epoch: 1270 loss: 0.0005104645970277488
# epoch: 1270 loss: 2.1860527992248535
# epoch: 1270 accuracy(object level): 0.9071814362872574
# epoch: 1270 accuracy(cluster level max): 0.8985797159431886
# epoch: 1270 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1280 loss: 23.879018783569336
# epoch: 1280 loss: 0.0005097629618830979
# epoch: 1280 loss: 2.184828042984009
# epoch: 1280 accuracy(object level): 0.9071814362872574
# epoch: 1280 accuracy(cluster level max): 0.8993798759751951
# epoch: 1280 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1290 loss: 23.873178482055664
# epoch: 1290 loss: 0.0005096114473417401
# epoch: 1290 loss: 2.1836256980895996
# epoch: 1290 accuracy(object level): 0.9069813962792559
# epoch: 1290 accuracy(cluster level max): 0.9001800360072014
# epoch: 1290 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1300 loss: 23.86396026611328
# epoch: 1300 loss: 0.0005092107458040118
# epoch: 1300 loss: 2.1824464797973633
# epoch: 1300 accuracy(object level): 0.9069813962792559
# epoch: 1300 accuracy(cluster level max): 0.9001800360072014
# epoch: 1300 accuracy(cluster level avg): 0.906381276255251
# epoch: 1310 loss: 23.8605899810791
# epoch: 1310 loss: 0.000508726283442229
# epoch: 1310 loss: 2.1812782287597656
# epoch: 1310 accuracy(object level): 0.9067813562712542
# epoch: 1310 accuracy(cluster level max): 0.9003800760152031
# epoch: 1310 accuracy(cluster level avg): 0.906381276255251
# epoch: 1320 loss: 23.85236930847168
# epoch: 1320 loss: 0.0005079520051367581
# epoch: 1320 loss: 2.1801326274871826
# epoch: 1320 accuracy(object level): 0.9067813562712542
# epoch: 1320 accuracy(cluster level max): 0.9003800760152031
# epoch: 1320 accuracy(cluster level avg): 0.906381276255251
# epoch: 1330 loss: 23.842815399169922
# epoch: 1330 loss: 0.0005075645167380571
# epoch: 1330 loss: 2.179009199142456
# epoch: 1330 accuracy(object level): 0.9067813562712542
# epoch: 1330 accuracy(cluster level max): 0.9003800760152031
# epoch: 1330 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1340 loss: 23.836973190307617
# epoch: 1340 loss: 0.0005071188788861036
# epoch: 1340 loss: 2.17789888381958
# epoch: 1340 accuracy(object level): 0.9065813162632527
# epoch: 1340 accuracy(cluster level max): 0.9001800360072014
# epoch: 1340 accuracy(cluster level avg): 0.906381276255251
# epoch: 1350 loss: 23.835107803344727
# epoch: 1350 loss: 0.0005065689911134541
# epoch: 1350 loss: 2.1768031120300293
# epoch: 1350 accuracy(object level): 0.9065813162632527
# epoch: 1350 accuracy(cluster level max): 0.9009801960392079
# epoch: 1350 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1360 loss: 23.827009201049805
# epoch: 1360 loss: 0.000506162061356008
# epoch: 1360 loss: 2.1757419109344482
# epoch: 1360 accuracy(object level): 0.9069813962792559
# epoch: 1360 accuracy(cluster level max): 0.9013802760552111
# epoch: 1360 accuracy(cluster level avg): 0.906381276255251
# epoch: 1370 loss: 23.821075439453125
# epoch: 1370 loss: 0.0005059019313193858
# epoch: 1370 loss: 2.1746959686279297
# epoch: 1370 accuracy(object level): 0.9069813962792559
# epoch: 1370 accuracy(cluster level max): 0.9011802360472094
# epoch: 1370 accuracy(cluster level avg): 0.906381276255251
# epoch: 1380 loss: 23.81268882751465
# epoch: 1380 loss: 0.0005056842928752303
# epoch: 1380 loss: 2.1736457347869873
# epoch: 1380 accuracy(object level): 0.9069813962792559
# epoch: 1380 accuracy(cluster level max): 0.9019803960792159
# epoch: 1380 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1390 loss: 23.810810089111328
# epoch: 1390 loss: 0.0005051762564107776
# epoch: 1390 loss: 2.172602891921997
# epoch: 1390 accuracy(object level): 0.9069813962792559
# epoch: 1390 accuracy(cluster level max): 0.9021804360872174
# epoch: 1390 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1400 loss: 23.808931350708008
# epoch: 1400 loss: 0.0005044655408710241
# epoch: 1400 loss: 2.1715893745422363
# epoch: 1400 accuracy(object level): 0.9069813962792559
# epoch: 1400 accuracy(cluster level max): 0.9023804760952191
# epoch: 1400 accuracy(cluster level avg): 0.9061812362472494
# epoch: 1410 loss: 23.794925689697266
# epoch: 1410 loss: 0.0005047133890911937
# epoch: 1410 loss: 2.170588254928589
# epoch: 1410 accuracy(object level): 0.9069813962792559
# epoch: 1410 accuracy(cluster level max): 0.9029805961192239
# epoch: 1410 accuracy(cluster level avg): 0.906381276255251
# epoch: 1420 loss: 23.790407180786133
# epoch: 1420 loss: 0.0005039480747655034
# epoch: 1420 loss: 2.169609785079956
# epoch: 1420 accuracy(object level): 0.9069813962792559
# epoch: 1420 accuracy(cluster level max): 0.9029805961192239
# epoch: 1420 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1430 loss: 23.78146743774414
# epoch: 1430 loss: 0.0005029364838264883
# epoch: 1430 loss: 2.168635606765747
# epoch: 1430 accuracy(object level): 0.9067813562712542
# epoch: 1430 accuracy(cluster level max): 0.9033806761352271
# epoch: 1430 accuracy(cluster level avg): 0.906381276255251
# epoch: 1440 loss: 23.778303146362305
# epoch: 1440 loss: 0.0005025165155529976
# epoch: 1440 loss: 2.1676602363586426
# epoch: 1440 accuracy(object level): 0.9067813562712542
# epoch: 1440 accuracy(cluster level max): 0.9041808361672334
# epoch: 1440 accuracy(cluster level avg): 0.9059811962392479
# epoch: 1450 loss: 23.78036880493164
# epoch: 1450 loss: 0.0005018038209527731
# epoch: 1450 loss: 2.166701555252075
# epoch: 1450 accuracy(object level): 0.9067813562712542
# epoch: 1450 accuracy(cluster level max): 0.9041808361672334
# epoch: 1450 accuracy(cluster level avg): 0.9065813162632527
# epoch: 1460 loss: 23.766563415527344
# epoch: 1460 loss: 0.0005015538772568107
# epoch: 1460 loss: 2.1657862663269043
# epoch: 1460 accuracy(object level): 0.9067813562712542
# epoch: 1460 accuracy(cluster level max): 0.9045809161832367
# epoch: 1460 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1470 loss: 23.76236343383789
# epoch: 1470 loss: 0.0005006827414035797
# epoch: 1470 loss: 2.164865255355835
# epoch: 1470 accuracy(object level): 0.9069813962792559
# epoch: 1470 accuracy(cluster level max): 0.9049809961992399
# epoch: 1470 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1480 loss: 23.758960723876953
# epoch: 1480 loss: 0.0005000779055990279
# epoch: 1480 loss: 2.163947820663452
# epoch: 1480 accuracy(object level): 0.9069813962792559
# epoch: 1480 accuracy(cluster level max): 0.9047809561912382
# epoch: 1480 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1490 loss: 23.755447387695312
# epoch: 1490 loss: 0.0004996435018256307
# epoch: 1490 loss: 2.163041114807129
# epoch: 1490 accuracy(object level): 0.9069813962792559
# epoch: 1490 accuracy(cluster level max): 0.905381076215243
# epoch: 1490 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1500 loss: 23.751102447509766
# epoch: 1500 loss: 0.0004990361048839986
# epoch: 1500 loss: 2.1621599197387695
# epoch: 1500 accuracy(object level): 0.9069813962792559
# epoch: 1500 accuracy(cluster level max): 0.9059811962392479
# epoch: 1500 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1510 loss: 23.741588592529297
# epoch: 1510 loss: 0.0004989478038623929
# epoch: 1510 loss: 2.1612799167633057
# epoch: 1510 accuracy(object level): 0.9069813962792559
# epoch: 1510 accuracy(cluster level max): 0.905381076215243
# epoch: 1510 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1520 loss: 23.73586082458496
# epoch: 1520 loss: 0.0004980853409506381
# epoch: 1520 loss: 2.160432815551758
# epoch: 1520 accuracy(object level): 0.9069813962792559
# epoch: 1520 accuracy(cluster level max): 0.9055811162232447
# epoch: 1520 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1530 loss: 23.73250389099121
# epoch: 1530 loss: 0.000497461121995002
# epoch: 1530 loss: 2.1595969200134277
# epoch: 1530 accuracy(object level): 0.9067813562712542
# epoch: 1530 accuracy(cluster level max): 0.9059811962392479
# epoch: 1530 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1540 loss: 23.72739601135254
# epoch: 1540 loss: 0.0004967569257132709
# epoch: 1540 loss: 2.1587560176849365
# epoch: 1540 accuracy(object level): 0.9067813562712542
# epoch: 1540 accuracy(cluster level max): 0.9057811562312462
# epoch: 1540 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1550 loss: 23.72675132751465
# epoch: 1550 loss: 0.0004962332313880324
# epoch: 1550 loss: 2.1579411029815674
# epoch: 1550 accuracy(object level): 0.9067813562712542
# epoch: 1550 accuracy(cluster level max): 0.906381276255251
# epoch: 1550 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1560 loss: 23.721332550048828
# epoch: 1560 loss: 0.00049570482224226
# epoch: 1560 loss: 2.15714693069458
# epoch: 1560 accuracy(object level): 0.9067813562712542
# epoch: 1560 accuracy(cluster level max): 0.906381276255251
# epoch: 1560 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1570 loss: 23.71430778503418
# epoch: 1570 loss: 0.0004954033647663891
# epoch: 1570 loss: 2.1563546657562256
# epoch: 1570 accuracy(object level): 0.9067813562712542
# epoch: 1570 accuracy(cluster level max): 0.9059811962392479
# epoch: 1570 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1580 loss: 23.71371078491211
# epoch: 1580 loss: 0.0004948401474393904
# epoch: 1580 loss: 2.1555614471435547
# epoch: 1580 accuracy(object level): 0.9067813562712542
# epoch: 1580 accuracy(cluster level max): 0.9067813562712542
# epoch: 1580 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1590 loss: 23.70469093322754
# epoch: 1590 loss: 0.0004938838537782431
# epoch: 1590 loss: 2.1547818183898926
# epoch: 1590 accuracy(object level): 0.9067813562712542
# epoch: 1590 accuracy(cluster level max): 0.9067813562712542
# epoch: 1590 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1600 loss: 23.702688217163086
# epoch: 1600 loss: 0.0004933554446324706
# epoch: 1600 loss: 2.154003620147705
# epoch: 1600 accuracy(object level): 0.9069813962792559
# epoch: 1600 accuracy(cluster level max): 0.9075815163032607
# epoch: 1600 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1610 loss: 23.704015731811523
# epoch: 1610 loss: 0.0004926798865199089
# epoch: 1610 loss: 2.1532516479492188
# epoch: 1610 accuracy(object level): 0.9069813962792559
# epoch: 1610 accuracy(cluster level max): 0.906381276255251
# epoch: 1610 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1620 loss: 23.69390869140625
# epoch: 1620 loss: 0.0004921118961647153
# epoch: 1620 loss: 2.152517080307007
# epoch: 1620 accuracy(object level): 0.9069813962792559
# epoch: 1620 accuracy(cluster level max): 0.9065813162632527
# epoch: 1620 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1630 loss: 23.69347381591797
# epoch: 1630 loss: 0.0004912473959848285
# epoch: 1630 loss: 2.1517882347106934
# epoch: 1630 accuracy(object level): 0.9069813962792559
# epoch: 1630 accuracy(cluster level max): 0.9065813162632527
# epoch: 1630 accuracy(cluster level avg): 0.907381476295259
# epoch: 1640 loss: 23.68781089782715
# epoch: 1640 loss: 0.0004906135145574808
# epoch: 1640 loss: 2.151060104370117
# epoch: 1640 accuracy(object level): 0.9069813962792559
# epoch: 1640 accuracy(cluster level max): 0.9065813162632527
# epoch: 1640 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1650 loss: 23.687761306762695
# epoch: 1650 loss: 0.00048984051682055
# epoch: 1650 loss: 2.1503543853759766
# epoch: 1650 accuracy(object level): 0.9071814362872574
# epoch: 1650 accuracy(cluster level max): 0.906381276255251
# epoch: 1650 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1660 loss: 23.677753448486328
# epoch: 1660 loss: 0.0004893805016763508
# epoch: 1660 loss: 2.1496682167053223
# epoch: 1660 accuracy(object level): 0.9071814362872574
# epoch: 1660 accuracy(cluster level max): 0.9057811562312462
# epoch: 1660 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1670 loss: 23.67729377746582
# epoch: 1670 loss: 0.0004888622788712382
# epoch: 1670 loss: 2.148982286453247
# epoch: 1670 accuracy(object level): 0.9069813962792559
# epoch: 1670 accuracy(cluster level max): 0.906381276255251
# epoch: 1670 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1680 loss: 23.6713809967041
# epoch: 1680 loss: 0.0004878946638200432
# epoch: 1680 loss: 2.1482949256896973
# epoch: 1680 accuracy(object level): 0.9069813962792559
# epoch: 1680 accuracy(cluster level max): 0.9067813562712542
# epoch: 1680 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1690 loss: 23.66818618774414
# epoch: 1690 loss: 0.0004870560369454324
# epoch: 1690 loss: 2.1476216316223145
# epoch: 1690 accuracy(object level): 0.9069813962792559
# epoch: 1690 accuracy(cluster level max): 0.9061812362472494
# epoch: 1690 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1700 loss: 23.66562843322754
# epoch: 1700 loss: 0.0004863710200879723
# epoch: 1700 loss: 2.1469712257385254
# epoch: 1700 accuracy(object level): 0.9067813562712542
# epoch: 1700 accuracy(cluster level max): 0.9069813962792559
# epoch: 1700 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1710 loss: 23.661977767944336
# epoch: 1710 loss: 0.0004861672059632838
# epoch: 1710 loss: 2.1463122367858887
# epoch: 1710 accuracy(object level): 0.9067813562712542
# epoch: 1710 accuracy(cluster level max): 0.9075815163032607
# epoch: 1710 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1720 loss: 23.66086196899414
# epoch: 1720 loss: 0.00048598673311062157
# epoch: 1720 loss: 2.1456823348999023
# epoch: 1720 accuracy(object level): 0.9067813562712542
# epoch: 1720 accuracy(cluster level max): 0.9079815963192639
# epoch: 1720 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1730 loss: 23.655750274658203
# epoch: 1730 loss: 0.00048516865354031324
# epoch: 1730 loss: 2.1450576782226562
# epoch: 1730 accuracy(object level): 0.9067813562712542
# epoch: 1730 accuracy(cluster level max): 0.9069813962792559
# epoch: 1730 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1740 loss: 23.65229606628418
# epoch: 1740 loss: 0.00048434961354359984
# epoch: 1740 loss: 2.1444263458251953
# epoch: 1740 accuracy(object level): 0.9067813562712542
# epoch: 1740 accuracy(cluster level max): 0.9077815563112622
# epoch: 1740 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1750 loss: 23.650510787963867
# epoch: 1750 loss: 0.00048313269508071244
# epoch: 1750 loss: 2.1438145637512207
# epoch: 1750 accuracy(object level): 0.9065813162632527
# epoch: 1750 accuracy(cluster level max): 0.9077815563112622
# epoch: 1750 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1760 loss: 23.652664184570312
# epoch: 1760 loss: 0.0004824317875318229
# epoch: 1760 loss: 2.1432323455810547
# epoch: 1760 accuracy(object level): 0.906381276255251
# epoch: 1760 accuracy(cluster level max): 0.9075815163032607
# epoch: 1760 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1770 loss: 23.64202117919922
# epoch: 1770 loss: 0.00048226380022242665
# epoch: 1770 loss: 2.1426212787628174
# epoch: 1770 accuracy(object level): 0.9065813162632527
# epoch: 1770 accuracy(cluster level max): 0.9077815563112622
# epoch: 1770 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1780 loss: 23.642410278320312
# epoch: 1780 loss: 0.0004814666463062167
# epoch: 1780 loss: 2.1420252323150635
# epoch: 1780 accuracy(object level): 0.9069813962792559
# epoch: 1780 accuracy(cluster level max): 0.9075815163032607
# epoch: 1780 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1790 loss: 23.63529396057129
# epoch: 1790 loss: 0.00048085831804201007
# epoch: 1790 loss: 2.1414592266082764
# epoch: 1790 accuracy(object level): 0.9069813962792559
# epoch: 1790 accuracy(cluster level max): 0.9081816363272655
# epoch: 1790 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1800 loss: 23.63663101196289
# epoch: 1800 loss: 0.00048072359641082585
# epoch: 1800 loss: 2.14089035987854
# epoch: 1800 accuracy(object level): 0.9069813962792559
# epoch: 1800 accuracy(cluster level max): 0.908381676335267
# epoch: 1800 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1810 loss: 23.630477905273438
# epoch: 1810 loss: 0.00047995607019402087
# epoch: 1810 loss: 2.140315294265747
# epoch: 1810 accuracy(object level): 0.9065813162632527
# epoch: 1810 accuracy(cluster level max): 0.9081816363272655
# epoch: 1810 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1820 loss: 23.634641647338867
# epoch: 1820 loss: 0.00047927512787282467
# epoch: 1820 loss: 2.139752149581909
# epoch: 1820 accuracy(object level): 0.906381276255251
# epoch: 1820 accuracy(cluster level max): 0.9089817963592719
# epoch: 1820 accuracy(cluster level avg): 0.907381476295259
# epoch: 1830 loss: 23.623809814453125
# epoch: 1830 loss: 0.00047822296619415283
# epoch: 1830 loss: 2.139220714569092
# epoch: 1830 accuracy(object level): 0.9065813162632527
# epoch: 1830 accuracy(cluster level max): 0.9085817163432687
# epoch: 1830 accuracy(cluster level avg): 0.907381476295259
# epoch: 1840 loss: 23.62887954711914
# epoch: 1840 loss: 0.0004778043366968632
# epoch: 1840 loss: 2.138669490814209
# epoch: 1840 accuracy(object level): 0.9065813162632527
# epoch: 1840 accuracy(cluster level max): 0.9079815963192639
# epoch: 1840 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1850 loss: 23.618501663208008
# epoch: 1850 loss: 0.0004772735992446542
# epoch: 1850 loss: 2.138127565383911
# epoch: 1850 accuracy(object level): 0.906381276255251
# epoch: 1850 accuracy(cluster level max): 0.9089817963592719
# epoch: 1850 accuracy(cluster level avg): 0.907381476295259
# epoch: 1860 loss: 23.61503791809082
# epoch: 1860 loss: 0.00047650793567299843
# epoch: 1860 loss: 2.137603282928467
# epoch: 1860 accuracy(object level): 0.906381276255251
# epoch: 1860 accuracy(cluster level max): 0.9089817963592719
# epoch: 1860 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1870 loss: 23.616512298583984
# epoch: 1870 loss: 0.0004755103145726025
# epoch: 1870 loss: 2.1371030807495117
# epoch: 1870 accuracy(object level): 0.9061812362472494
# epoch: 1870 accuracy(cluster level max): 0.9095819163832767
# epoch: 1870 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1880 loss: 23.611064910888672
# epoch: 1880 loss: 0.0004752695094794035
# epoch: 1880 loss: 2.1366126537323
# epoch: 1880 accuracy(object level): 0.9061812362472494
# epoch: 1880 accuracy(cluster level max): 0.9089817963592719
# epoch: 1880 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1890 loss: 23.609848022460938
# epoch: 1890 loss: 0.00047467148397117853
# epoch: 1890 loss: 2.136096239089966
# epoch: 1890 accuracy(object level): 0.9061812362472494
# epoch: 1890 accuracy(cluster level max): 0.9085817163432687
# epoch: 1890 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1900 loss: 23.608230590820312
# epoch: 1900 loss: 0.00047377654118463397
# epoch: 1900 loss: 2.1356005668640137
# epoch: 1900 accuracy(object level): 0.9059811962392479
# epoch: 1900 accuracy(cluster level max): 0.9079815963192639
# epoch: 1900 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1910 loss: 23.602272033691406
# epoch: 1910 loss: 0.0004732044180855155
# epoch: 1910 loss: 2.135132312774658
# epoch: 1910 accuracy(object level): 0.9059811962392479
# epoch: 1910 accuracy(cluster level max): 0.9085817163432687
# epoch: 1910 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1920 loss: 23.598430633544922
# epoch: 1920 loss: 0.00047238494153134525
# epoch: 1920 loss: 2.134650945663452
# epoch: 1920 accuracy(object level): 0.9061812362472494
# epoch: 1920 accuracy(cluster level max): 0.909381876375275
# epoch: 1920 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1930 loss: 23.597148895263672
# epoch: 1930 loss: 0.0004718440177384764
# epoch: 1930 loss: 2.1341707706451416
# epoch: 1930 accuracy(object level): 0.9059811962392479
# epoch: 1930 accuracy(cluster level max): 0.9087817563512702
# epoch: 1930 accuracy(cluster level avg): 0.907381476295259
# epoch: 1940 loss: 23.605375289916992
# epoch: 1940 loss: 0.00047132791951298714
# epoch: 1940 loss: 2.133718967437744
# epoch: 1940 accuracy(object level): 0.9059811962392479
# epoch: 1940 accuracy(cluster level max): 0.9087817563512702
# epoch: 1940 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1950 loss: 23.604839324951172
# epoch: 1950 loss: 0.00047067279228940606
# epoch: 1950 loss: 2.1332712173461914
# epoch: 1950 accuracy(object level): 0.9059811962392479
# epoch: 1950 accuracy(cluster level max): 0.9085817163432687
# epoch: 1950 accuracy(cluster level avg): 0.9067813562712542
# epoch: 1960 loss: 23.59595489501953
# epoch: 1960 loss: 0.0004697670228779316
# epoch: 1960 loss: 2.1328275203704834
# epoch: 1960 accuracy(object level): 0.9057811562312462
# epoch: 1960 accuracy(cluster level max): 0.9091818363672735
# epoch: 1960 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1970 loss: 23.59123420715332
# epoch: 1970 loss: 0.0004690258647315204
# epoch: 1970 loss: 2.1323773860931396
# epoch: 1970 accuracy(object level): 0.9057811562312462
# epoch: 1970 accuracy(cluster level max): 0.9081816363272655
# epoch: 1970 accuracy(cluster level avg): 0.9069813962792559
# epoch: 1980 loss: 23.589004516601562
# epoch: 1980 loss: 0.0004681787686422467
# epoch: 1980 loss: 2.131925106048584
# epoch: 1980 accuracy(object level): 0.9057811562312462
# epoch: 1980 accuracy(cluster level max): 0.9089817963592719
# epoch: 1980 accuracy(cluster level avg): 0.9071814362872574
# epoch: 1990 loss: 23.582860946655273
# epoch: 1990 loss: 0.0004671526839956641
# epoch: 1990 loss: 2.1314754486083984
# epoch: 1990 accuracy(object level): 0.9057811562312462
# epoch: 1990 accuracy(cluster level max): 0.9085817163432687
# epoch: 1990 accuracy(cluster level avg): 0.907381476295259
# Training overall net. Done!

# %%
import scipy.io
if False:
    scipy.io.savemat('trial_tf_workplace', 
                     {'monitor_q_zxl':monitor_q_zxl})
